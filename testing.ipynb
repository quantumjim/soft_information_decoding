# %%
import matplotlib.pyplot as plt

# Data for uninformed error rates
x_uninformed = [7, 30]  # Code distances
y_uninformed_10 = [302/10000, 228/50000]  # 10% rate
y_uninformed_20 = [514/10000, 923/10000]  # 20% rate

# Data for soft information error rates
y_soft_10 = [130/10000, 1/50000]  # 10% rate
y_soft_20 = [164/10000, 5/10000]  # 20% rate

# Plotting the data
plt.figure(figsize=(10, 6), dpi=300)

# Uninformed error rates
plt.plot(x_uninformed, y_uninformed_10, label='Uninformed 10%', linestyle='--', color='blue', marker='o')
plt.plot(x_uninformed, y_uninformed_20, label='Uninformed 20%', linestyle='--', color='red', marker='o')

# Soft information error rates
plt.plot(x_uninformed, y_soft_10, label='Soft Info 10%', linestyle='-', color='blue', marker='o')
plt.plot(x_uninformed, y_soft_20, label='Soft Info 20%', linestyle='-', color='red', marker='o')

# Adding labels and title
plt.xlabel('Code Distance (number of qubits)')
plt.ylabel('Logical Error Rate')
plt.yscale('log')
plt.title('Error Rates vs Code Distance for differend decoder (log scale))')
plt.xticks([7, 30])  # Set x-ticks to show only 7 and 30
plt.legend()

# Enhancing the visual appeal
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for uninformed error rates
x_uninformed = [7, 30]  # Code distances
y_uninformed_10 = [302/10000, 228/50000]  # 10% rate
y_uninformed_20 = [514/10000, 923/10000]  # 20% rate

# Data for soft information error rates
y_soft_10 = [130/10000, 1/50000]  # 10% rate
y_soft_20 = [164/10000, 5/10000]  # 20% rate

# Plotting the data
plt.figure(figsize=(10, 6), dpi=300)

# Uninformed error rates
plt.plot(x_uninformed, y_uninformed_10, label='Uninformed 10%', linestyle='--', color='blue', marker='o')
plt.plot(x_uninformed, y_uninformed_20, label='Uninformed 20%', linestyle='--', color='red', marker='o')

# Soft information error rates
plt.plot(x_uninformed, y_soft_10, label='Soft Info 10%', linestyle='-', color='blue', marker='o')
plt.plot(x_uninformed, y_soft_20, label='Soft Info 20%', linestyle='-', color='red', marker='o')

# Filling the area between 10% uninformed and 10% soft information
# plt.fill_between(x_uninformed, y_uninformed_10, y_soft_10, color='grey', alpha=0.4)

# Adding labels and title
plt.xlabel('Code Distance (number of qubits)')
plt.ylabel('Logical Error Rate')
plt.yscale('log')
plt.title('Error Rates vs Code Distance for different decoders (log scale)')
plt.xticks([7, 30])  # Set x-ticks to show only 7 and 30
plt.legend()

# Enhancing the visual appeal
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for uninformed error rates
x_uninformed = [7, 30]  # Code distances
y_uninformed_10 = [302/10000, 228/50000]  # 10% rate
y_uninformed_20 = [514/10000, 923/10000]  # 20% rate

# Data for soft information error rates
y_soft_10 = [130/10000, 1/50000]  # 10% rate
y_soft_20 = [164/10000, 5/10000]  # 20% rate

# Plotting the data
plt.figure(figsize=(10, 6), dpi=300)

# Uninformed error rates
# plt.plot(x_uninformed, y_uninformed_10, label='Uninformed 10%', linestyle='--', color='blue', marker='o')
plt.plot(x_uninformed, y_uninformed_20, label='Uninformed 20%', linestyle='--', color='red', marker='o')

# Soft information error rates
# plt.plot(x_uninformed, y_soft_10, label='Soft Info 10%', linestyle='-', color='blue', marker='o')
plt.plot(x_uninformed, y_soft_20, label='Soft Info 20%', linestyle='-', color='red', marker='o')

# Adding labels and title
plt.xlabel('Code Distance (number of qubits)')
plt.ylabel('Logical Error Rate')
plt.yscale('log')
plt.title('Error Rates vs Code Distance for different decoders')
plt.xticks([7, 30])  # Set x-ticks to show only 7 and 30
plt.legend()

# Enhancing the visual appeal
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()

# %% [markdown]
# # Only 10%

# %%
import matplotlib.pyplot as plt

# Data for uninformed error rates
x_uninformed = [7, 11, 15, 21, 25, 30]  # Code distances
y_uninformed_10 = [302/10000, 303/10000, 234/10000, 192/10000, 845/50000, 228/50000]  # 10% rate
# y_uninformed_20 = [514/10000, 923/10000]  # 20% rate

# Data for soft information error rates
y_soft_10 = [130/10000, 34/10000, 17/10000, 5/10000, 6/50000, 1/50000]  # 10% rate
# y_soft_20 = [164/10000, 5/10000]  # 20% rate

# Plotting the data
plt.figure(figsize=(10, 6), dpi=300)

# Uninformed error rates
plt.plot(x_uninformed, y_uninformed_10, label='Uninformed', linestyle='-', color='red', marker='o')
# plt.plot(x_uninformed, y_uninformed_20, label='Uninformed 20%', linestyle='--', color='red', marker='o')

# Soft information error rates
plt.plot(x_uninformed, y_soft_10, label='Informed', linestyle='-', color='blue', marker='o')
# plt.plot(x_uninformed, y_soft_20, label='Soft Info 20%', linestyle='-', color='red', marker='o')

# Filling the area between 10% uninformed and 10% soft information
plt.fill_between(x_uninformed, y_uninformed_10, y_soft_10, color='grey', alpha=0.4)

# Adding labels and title
plt.xlabel('Code Distance (number of qubits)')
plt.ylabel('Logical Error Rate')
plt.yscale('log')
plt.title('Error Rates vs Code Distance for different decoders (log scale) with 10% ambiguous points')
plt.xticks(x_uninformed)  # Set x-ticks to show only 7 and 30
plt.legend()

# Enhancing the visual appeal
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified logarithmic function
def modified_log_function(x, k=1000):
    return np.log(1 + k * x) / np.log(1 + k)

# Generate x values from 0 to 1
x_values = np.linspace(0, 1, 500)

# Compute y values using the modified logarithmic function
y_values = [modified_log_function(x) for x in x_values]

# Plot the function
plt.figure(dpi=300)
plt.plot(x_values, y_values, color='blue', linewidth=2)
plt.title('Performance of Approximate Decoder Relative to Exact Decoder')
plt.xlabel('Accuracy (# Bits)')
plt.ylabel('Performance Ratio (Approximate / Exact)')
plt.grid(True)
plt.show()
