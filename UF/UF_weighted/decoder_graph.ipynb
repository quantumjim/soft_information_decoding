# %%
import sys
sys.path.append("UF")
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from qiskit_qec.circuits import ArcCircuit, RepetitionCodeCircuit
from qiskit_qec.decoders import UnionFindDecoder
from qiskit_aer import AerSimulator

from qiskit.providers.fake_provider import FakeSherbrooke

# %%
links = [[0, 1, 2], [2, 3, 4], [4, 5, 6], [6, 7, 0]] # q1, a, q2 
T = 3 # number of syndrome measurement rounds

# code = ArcCircuit(links, T, basis='zz',logical='1') 
#qc = code.circuit['zz']

code = RepetitionCodeCircuit(5, T, xbasis=False, resets=True, barriers=True) 
qc = code.circuit['0']
print(qc.draw(fold=-1))
AerSimulator().run(qc).result().get_counts()
# Out:
#                      ░ ┌───┐               ┌───┐                ░ ┌─┐          ░       ░ ┌───┐               ┌───┐                ░ ┌─┐          ░       ░ ┌───┐               ┌───┐                ░ ┌─┐
#       link_qubit_0: ─░─┤ X ├───────────────┤ X ├────────────────░─┤M├──────────░──|0>──░─┤ X ├───────────────┤ X ├────────────────░─┤M├──────────░──|0>──░─┤ X ├───────────────┤ X ├────────────────░─┤M├────────────────────────
#                      ░ └─┬─┘┌───┐          └─┬─┘┌───┐           ░ └╥┘┌─┐       ░       ░ └─┬─┘┌───┐          └─┬─┘┌───┐           ░ └╥┘┌─┐       ░       ░ └─┬─┘┌───┐          └─┬─┘┌───┐           ░ └╥┘┌─┐
#       link_qubit_1: ─░───┼──┤ X ├────────────┼──┤ X ├───────────░──╫─┤M├───────░──|0>──░───┼──┤ X ├────────────┼──┤ X ├───────────░──╫─┤M├───────░──|0>──░───┼──┤ X ├────────────┼──┤ X ├───────────░──╫─┤M├─────────────────────
#                      ░   │  └─┬─┘┌───┐       │  └─┬─┘┌───┐      ░  ║ └╥┘┌─┐    ░       ░   │  └─┬─┘┌───┐       │  └─┬─┘┌───┐      ░  ║ └╥┘┌─┐    ░       ░   │  └─┬─┘┌───┐       │  └─┬─┘┌───┐      ░  ║ └╥┘┌─┐
#       link_qubit_2: ─░───┼────┼──┤ X ├───────┼────┼──┤ X ├──────░──╫──╫─┤M├────░──|0>──░───┼────┼──┤ X ├───────┼────┼──┤ X ├──────░──╫──╫─┤M├────░──|0>──░───┼────┼──┤ X ├───────┼────┼──┤ X ├──────░──╫──╫─┤M├──────────────────
#                      ░   │    │  └─┬─┘┌───┐  │    │  └─┬─┘┌───┐ ░  ║  ║ └╥┘┌─┐ ░       ░   │    │  └─┬─┘┌───┐  │    │  └─┬─┘┌───┐ ░  ║  ║ └╥┘┌─┐ ░       ░   │    │  └─┬─┘┌───┐  │    │  └─┬─┘┌───┐ ░  ║  ║ └╥┘┌─┐
#       link_qubit_3: ─░───┼────┼────┼──┤ X ├──┼────┼────┼──┤ X ├─░──╫──╫──╫─┤M├─░──|0>──░───┼────┼────┼──┤ X ├──┼────┼────┼──┤ X ├─░──╫──╫──╫─┤M├─░──|0>──░───┼────┼────┼──┤ X ├──┼────┼────┼──┤ X ├─░──╫──╫──╫─┤M├───────────────
#                      ░   │    │    │  └─┬─┘  │    │    │  └─┬─┘ ░  ║  ║  ║ └╥┘ ░       ░   │    │    │  └─┬─┘  │    │    │  └─┬─┘ ░  ║  ║  ║ └╥┘ ░       ░   │    │    │  └─┬─┘  │    │    │  └─┬─┘ ░  ║  ║  ║ └╥┘┌─┐
#       code_qubit_0: ─░───■────┼────┼────┼────┼────┼────┼────┼───░──╫──╫──╫──╫──░───────░───■────┼────┼────┼────┼────┼────┼────┼───░──╫──╫──╫──╫──░───────░───■────┼────┼────┼────┼────┼────┼────┼───░──╫──╫──╫──╫─┤M├────────────
#                      ░        │    │    │    │    │    │    │   ░  ║  ║  ║  ║  ░       ░        │    │    │    │    │    │    │   ░  ║  ║  ║  ║  ░       ░        │    │    │    │    │    │    │   ░  ║  ║  ║  ║ └╥┘┌─┐
#       code_qubit_1: ─░────────■────┼────┼────■────┼────┼────┼───░──╫──╫──╫──╫──░───────░────────■────┼────┼────■────┼────┼────┼───░──╫──╫──╫──╫──░───────░────────■────┼────┼────■────┼────┼────┼───░──╫──╫──╫──╫──╫─┤M├─────────
#                      ░             │    │         │    │    │   ░  ║  ║  ║  ║  ░       ░             │    │         │    │    │   ░  ║  ║  ║  ║  ░       ░             │    │         │    │    │   ░  ║  ║  ║  ║  ║ └╥┘┌─┐
#       code_qubit_2: ─░─────────────■────┼─────────■────┼────┼───░──╫──╫──╫──╫──░───────░─────────────■────┼─────────■────┼────┼───░──╫──╫──╫──╫──░───────░─────────────■────┼─────────■────┼────┼───░──╫──╫──╫──╫──╫──╫─┤M├──────
#                      ░                  │              │    │   ░  ║  ║  ║  ║  ░       ░                  │              │    │   ░  ║  ║  ║  ║  ░       ░                  │              │    │   ░  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
#       code_qubit_3: ─░──────────────────■──────────────■────┼───░──╫──╫──╫──╫──░───────░──────────────────■──────────────■────┼───░──╫──╫──╫──╫──░───────░──────────────────■──────────────■────┼───░──╫──╫──╫──╫──╫──╫──╫─┤M├───
#                      ░                                      │   ░  ║  ║  ║  ║  ░       ░                                      │   ░  ║  ║  ║  ║  ░       ░                                      │   ░  ║  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
#       code_qubit_4: ─░──────────────────────────────────────■───░──╫──╫──╫──╫──░───────░──────────────────────────────────────■───░──╫──╫──╫──╫──░───────░──────────────────────────────────────■───░──╫──╫──╫──╫──╫──╫──╫──╫─┤M├
#                      ░                                          ░  ║  ║  ║  ║  ░       ░                                          ░  ║  ║  ║  ║  ░       ░                                          ░  ║  ║  ║  ║  ║  ║  ║  ║ └╥┘
# round_0_link_bit: 4/═══════════════════════════════════════════════╩══╩══╩══╩════════════════════════════════════════════════════════╬══╬══╬══╬════════════════════════════════════════════════════════╬══╬══╬══╬══╬══╬══╬══╬══╬═
#                                                                    0  1  2  3                                                        ║  ║  ║  ║                                                        ║  ║  ║  ║  ║  ║  ║  ║  ║
# round_1_link_bit: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩════════════════════════════════════════════════════════╬══╬══╬══╬══╬══╬══╬══╬══╬═
#                                                                                                                                      0  1  2  3                                                        ║  ║  ║  ║  ║  ║  ║  ║  ║
# round_2_link_bit: 4/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩══╬══╬══╬══╬══╬═
#                                                                                                                                                                                                        0  1  2  3  ║  ║  ║  ║  ║
#         code_bit: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                                                                                                                                                                                    0  1  2  3  4
# {'00000 0000 0000 0000': 1024}

# %%
#decoder = UnionFindDecoder(ArcCircuit(links, T))
decoder = UnionFindDecoder(code)
graph = decoder.decoding_graph.graph
graph.nodes()

sorted_nodes = sorted(graph.nodes(), key=lambda x: x['time'] if x['time'] is not None else -1)
sorted_nodes
# Out:
# [{'is_boundary': True, 'time': None, 'qubits': [0], 'index': 0, 'properties': {}},
#  {'is_boundary': True, 'time': None, 'qubits': [4], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [3, 4], 'index': 3, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [3, 4], 'index': 3, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [3, 4], 'index': 3, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [3, 4], 'index': 3, 'properties': {}}]

# %%
max_index = max(graph.nodes()[node]['index'] for node in graph.node_indexes())
max_index
# Out:
# 3

# %% [markdown]
# # Edge functions

# %%
print("graph.edges():", graph.edges())
print("graph.edge_list():", graph.edge_list())
print(graph.get_edge_data(0, 1))

graph.edges()[0]['weight'] = 0.5
print(graph.edges()[0])

graph.get_edge_data(0, 1)
print(graph.edge_list()[0][0])
print(graph.nodes()[graph.edge_list()[11][1]])
# Out:
# graph.edges(): [{'qubits': [], 'weight': 0.5, 'properties': {}}, {'qubits': [0], 'weight': 1, 'properties': {}}, {'qubits': [0], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [4], 'weight': 1, 'properties': {}}, {'qubits': [4], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [0], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [4], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [], 'weight': 1, 'properties': {}}, {'qubits': [0], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [1], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [2], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [3], 'weight': 1, 'properties': {}}, {'qubits': [4], 'weight': 1, 'properties': {}}]
# graph.edge_list(): EdgeList[(0, 1), (2, 1), (2, 0), (3, 4), (0, 4), (0, 3), (1, 4), (5, 6), (3, 6), (3, 5), (4, 6), (7, 8), (5, 8), (5, 7), (6, 8), (9, 8), (9, 7), (1, 10), (4, 11), (6, 12), (8, 13), (2, 10), (1, 11), (10, 11), (4, 12), (11, 12), (6, 13), (12, 13), (9, 13), (10, 14), (11, 15), (12, 16), (13, 17), (2, 14), (10, 15), (14, 15), (11, 16), (15, 16), (12, 17), (16, 17), (9, 17)]
# {'qubits': [], 'weight': 0.5, 'properties': {}}
# {'qubits': [], 'weight': 0.5, 'properties': {}}
# 0
# {'is_boundary': False, 'time': 1, 'qubits': [3, 4], 'index': 3, 'properties': {}}

# %% [markdown]
# # Plotter function

# %%
# %load_ext autoreload
# %autoreload 
sorted_nodes
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [{'is_boundary': True, 'time': None, 'qubits': [0], 'index': 0, 'properties': {}},
#  {'is_boundary': True, 'time': None, 'qubits': [4], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 0, 'qubits': [3, 4], 'index': 3, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 1, 'qubits': [3, 4], 'index': 3, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 2, 'qubits': [3, 4], 'index': 3, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [0, 1], 'index': 0, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [1, 2], 'index': 1, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [2, 3], 'index': 2, 'properties': {}},
#  {'is_boundary': False, 'time': 3, 'qubits': [3, 4], 'index': 3, 'properties': {}}]

# %%
import sys
sys.path.append("UF")

import networkx as nx

from plot_functions import rx_draw, rx_draw_2D

rx_draw_2D(graph)

# %% [markdown]
# # Graphviz try

# %%
from retworkx.visualization import graphviz_draw

def my_node_attributes(node):
    return {'label': str(node)}

def my_edge_attributes(edge):
    return {'color': 'red'}

graphviz_draw(graph=graph, filename='output.dot', node_attr_fn=my_node_attributes, edge_attr_fn=my_edge_attributes)

# %% [markdown]
# # Networkx visualization

# %%
import retworkx as rx
import networkx as nx
import matplotlib.pyplot as plt

# Create a new NetworkX Graph object
G_nx = nx.Graph()

# Add nodes to NetworkX graph
for node in graph.node_indexes():
    G_nx.add_node(node)

# Add edges to NetworkX graph
for edge in graph.edge_list():
    src, tgt = edge
    G_nx.add_edge(src, tgt)

# Now you can plot using NetworkX and Matplotlib
import matplotlib.pyplot as plt
nx.draw(G_nx, with_labels=True, pos=nx.spring_layout(G_nx))
plt.show()
