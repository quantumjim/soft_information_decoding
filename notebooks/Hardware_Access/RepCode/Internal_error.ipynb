# %%
from Scratch import metadata_loader

md = metadata_loader(True, True)
md = md[md["notebook_name"] == "diff_rounds_dist_55"]
md = md[md["backend_name"] == 'ibm_sherbrooke']
md = md[md["job_status"] != "JobStatus.QUEUED"]
#md = md[md["descr"]== "Run bigger Repetition codes"]
md = md[md["distance"] == 55]
md = md.sort_values(by=['rounds'])



md[:]
# Out:
#                         creation_date        notebook_name    backend_name  \
# 339  2023-10-30 18:57:33.512924+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 340  2023-10-30 18:57:54.732931+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 347  2023-10-30 19:00:24.981397+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 348  2023-10-30 19:00:46.806827+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 355  2023-10-30 19:03:23.978443+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 356  2023-10-30 19:03:47.368539+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 371  2023-10-30 19:33:08.592055+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 372  2023-10-30 19:33:32.064676+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 379  2023-10-30 19:36:11.207338+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 380  2023-10-30 19:36:33.543693+01:00  diff_rounds_dist_55  ibm_sherbrooke
# 387  2023-10-30 19:39:22.394692+01:00  diff_rounds_dist_55  ibm_sherbrooke
# ...
