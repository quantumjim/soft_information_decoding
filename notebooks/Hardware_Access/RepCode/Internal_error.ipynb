# %%
from Scratch import metadata_loader

md = metadata_loader(True, True)
md = md[md["notebook_name"] == "bigger_rep_codes"]
md = md[md["backend_name"] == 'ibm_nazca']
md = md[md["job_status"] != "JobStatus.QUEUED"]
md = md[md["descr"]== "Run bigger Repetition codes"]
#md = md[md["distance"] == 55]
md = md.sort_values(by=['rounds'])



md[:]
# Out:
#                        creation_date     notebook_name backend_name  \
# 64  2023-10-29 14:45:46.957013+01:00  bigger_rep_codes    ibm_nazca
# 63  2023-10-29 14:45:36.307154+01:00  bigger_rep_codes    ibm_nazca
# 56  2023-10-29 14:44:20.790250+01:00  bigger_rep_codes    ibm_nazca
# 55  2023-10-29 14:44:13.303112+01:00  bigger_rep_codes    ibm_nazca
# 72  2023-10-29 14:47:08.372330+01:00  bigger_rep_codes    ibm_nazca
# 71  2023-10-29 14:46:57.513106+01:00  bigger_rep_codes    ibm_nazca
# 80  2023-10-29 14:49:02.841937+01:00  bigger_rep_codes    ibm_nazca
# 79  2023-10-29 14:48:46.334985+01:00  bigger_rep_codes    ibm_nazca
# 88  2023-10-29 14:51:52.099090+01:00  bigger_rep_codes    ibm_nazca
# 87  2023-10-29 14:51:27.216704+01:00  bigger_rep_codes    ibm_nazca
# 96  2023-10-29 14:55:56.051433+01:00  bigger_rep_codes    ibm_nazca
# 95  2023-10-29 14:55:18.054620+01:00  bigger_rep_codes    ibm_nazca
#
#                   job_id tags    shots tags_xp sampled_state  num_qubits  \
# 64  cmz642g3r3vg008wf9cg   []  10000.0     NaN           NaN         NaN
# 63  cmz64003r3vg008wf9bg   []  10000.0     NaN           NaN         NaN
# 56  cmz63d5vayrg008sp2bg   []  10000.0     NaN           NaN         NaN
# 55  cmz63bdvayrg008sp2b0   []  10000.0     NaN           NaN         NaN
# 72  cmz64q2rmwhg008bswyg   []   2500.0     NaN           NaN         NaN
# 71  cmz64madaqbg008shr50   []   2500.0     NaN           NaN         NaN
# 80  cmz65kpvayrg008sp2e0   []   1111.0     NaN           NaN         NaN
# 79  cmz65fn3r3vg008wf9kg   []   1111.0     NaN           NaN         NaN
# 88  cmz66y3rmwhg008bsx40   []    625.0     NaN           NaN         NaN
# 87  cmz66qtp1am0008q1fe0   []    625.0     NaN           NaN         NaN
# 96  cmz68v3rmwhg008bsxa0   []    400.0     NaN           NaN         NaN
# 95  cmz68hj3r3vg008wf9y0   []    400.0     NaN           NaN         NaN
#
#          job_status extra  optimization_level                   code  \
# 64   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 63   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 56   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 55   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 72   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 71   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 80   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 79   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 88  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 87  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 96  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 95  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
#
#     distance rounds logical        layout                        descr
# 64      10.0     10       1  _is_hex=True  Run bigger Repetition codes
# 63      10.0     10       0  _is_hex=True  Run bigger Repetition codes
# 56      10.0     10       1  _is_hex=True  Run bigger Repetition codes
# 55      10.0     10       0  _is_hex=True  Run bigger Repetition codes
# 72      20.0     20       1  _is_hex=True  Run bigger Repetition codes
# 71      20.0     20       0  _is_hex=True  Run bigger Repetition codes
# 80      30.0     30       1  _is_hex=True  Run bigger Repetition codes
# 79      30.0     30       0  _is_hex=True  Run bigger Repetition codes
# 88      40.0     40       1  _is_hex=True  Run bigger Repetition codes
# 87      40.0     40       0  _is_hex=True  Run bigger Repetition codes
# 96      50.0     50       1  _is_hex=True  Run bigger Repetition codes
# 95      50.0     50       0  _is_hex=True  Run bigger Repetition codes
