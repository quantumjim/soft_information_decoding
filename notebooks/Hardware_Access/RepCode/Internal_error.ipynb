# %%
from Scratch import metadata_loader

md = metadata_loader(True, True)
md = md[md["notebook_name"] == "diff_rounds_dist_55"]
md = md[md["backend_name"] == 'ibm_nazca']
md = md[md["distance"] == 40]
#md = md[md["job_status"]=='JobStatus.DONE']
md = md.sort_values(by=['rounds'])




md[:]
# Out:
#                         creation_date        notebook_name backend_name  \
# 301  2023-10-30 18:46:13.164293+01:00  diff_rounds_dist_55    ibm_nazca
# 302  2023-10-30 18:46:26.771526+01:00  diff_rounds_dist_55    ibm_nazca
# 310  2023-10-30 18:48:34.844943+01:00  diff_rounds_dist_55    ibm_nazca
# 309  2023-10-30 18:48:20.441873+01:00  diff_rounds_dist_55    ibm_nazca
# 317  2023-10-30 18:50:33.265431+01:00  diff_rounds_dist_55    ibm_nazca
# 318  2023-10-30 18:50:48.622767+01:00  diff_rounds_dist_55    ibm_nazca
# 325  2023-10-30 18:52:56.006742+01:00  diff_rounds_dist_55    ibm_nazca
# 326  2023-10-30 18:53:12.210572+01:00  diff_rounds_dist_55    ibm_nazca
# 333  2023-10-30 18:55:30.085467+01:00  diff_rounds_dist_55    ibm_nazca
# 334  2023-10-30 18:55:48.239658+01:00  diff_rounds_dist_55    ibm_nazca
# 341  2023-10-30 18:58:17.310135+01:00  diff_rounds_dist_55    ibm_nazca
# 342  2023-10-30 18:58:36.431004+01:00  diff_rounds_dist_55    ibm_nazca
# 349  2023-10-30 19:01:10.391599+01:00  diff_rounds_dist_55    ibm_nazca
# 350  2023-10-30 19:01:30.548103+01:00  diff_rounds_dist_55    ibm_nazca
# 363  2023-10-30 19:24:21.524197+01:00  diff_rounds_dist_55    ibm_nazca
# 357  2023-10-30 19:04:12.491874+01:00  diff_rounds_dist_55    ibm_nazca
# 358  2023-10-30 19:04:34.319837+01:00  diff_rounds_dist_55    ibm_nazca
# 362  2023-10-30 19:23:27.232411+01:00  diff_rounds_dist_55    ibm_nazca
# 365  2023-10-30 19:30:38.452587+01:00  diff_rounds_dist_55    ibm_nazca
# 366  2023-10-30 19:30:58.588583+01:00  diff_rounds_dist_55    ibm_nazca
# 373  2023-10-30 19:33:55.082853+01:00  diff_rounds_dist_55    ibm_nazca
# 374  2023-10-30 19:34:16.380610+01:00  diff_rounds_dist_55    ibm_nazca
# 381  2023-10-30 19:36:57.544341+01:00  diff_rounds_dist_55    ibm_nazca
# 382  2023-10-30 19:37:18.296267+01:00  diff_rounds_dist_55    ibm_nazca
# 389  2023-10-30 19:40:15.346021+01:00  diff_rounds_dist_55    ibm_nazca
# 390  2023-10-30 19:40:38.594841+01:00  diff_rounds_dist_55    ibm_nazca
# 395  2023-10-30 20:09:02.578100+01:00  diff_rounds_dist_55    ibm_nazca
# 396  2023-10-30 20:09:27.299451+01:00  diff_rounds_dist_55    ibm_nazca
# 403  2023-10-30 20:12:38.462911+01:00  diff_rounds_dist_55    ibm_nazca
# 404  2023-10-30 20:13:06.804787+01:00  diff_rounds_dist_55    ibm_nazca
# 411  2023-10-30 20:16:31.471771+01:00  diff_rounds_dist_55    ibm_nazca
# 412  2023-10-30 20:16:58.088424+01:00  diff_rounds_dist_55    ibm_nazca
# 419  2023-10-30 20:20:46.807320+01:00  diff_rounds_dist_55    ibm_nazca
# 420  2023-10-30 20:21:16.989775+01:00  diff_rounds_dist_55    ibm_nazca
# 427  2023-10-30 20:25:01.137790+01:00  diff_rounds_dist_55    ibm_nazca
# 428  2023-10-30 20:25:31.439934+01:00  diff_rounds_dist_55    ibm_nazca
#
#                    job_id tags  shots tags_xp sampled_state  num_qubits  \
# 301  cmzyqsfrmwhg008fdzk0   []  625.0     NaN           NaN         NaN
# 302  cmzyqwqvayrg008cpzc0   []  625.0     NaN           NaN         NaN
# 310  cmzyrwkvayrg008cpzmg   []  625.0     NaN           NaN         NaN
# 309  cmzyrs3daqbg008sk8v0   []  625.0     NaN           NaN         NaN
# 317  cmzystfvcq70008qff10   []  625.0     NaN           NaN         NaN
# 318  cmzysy7p1am0008q2rr0   []  625.0     NaN           NaN         NaN
# 325  cmzytxvrmwhg008fe050   []  625.0     NaN           NaN         NaN
# 326  cmzyv24p1am0008q2s0g   []  625.0     NaN           NaN         NaN
# 333  cmzyw4gdaqbg008sk9cg   []  625.0     NaN           NaN         NaN
# 334  cmzyw91daqbg008sk9eg   []  625.0     NaN           NaN         NaN
# 341  cmzyxedp1am0008q2se0   []  625.0     NaN           NaN         NaN
# 342  cmzyxk6vayrg008cq0d0   []  625.0     NaN           NaN         NaN
# 349  cmzyyskvayrg008cq0jg   []  625.0     NaN           NaN         NaN
# 350  cmzyyykp1am0008q2sr0   []  625.0     NaN           NaN         NaN
# 363  cmzz9ne3r3vg008wgq9g   []  625.0     NaN           NaN         NaN
# 357  cmzz070vayrg008cq0t0   []  625.0     NaN           NaN         NaN
# 358  cmzz0chdaqbg008ska1g   []  625.0     NaN           NaN         NaN
# 362  cmzz97wdaqbg008skbc0   []  625.0     NaN           NaN         NaN
# 365  cmzzckj3r3vg008wgqf0   []  625.0     NaN           NaN         NaN
# 366  cmzzcrkrmwhg008fe2dg   []  625.0     NaN           NaN         NaN
# 373  cmzze4rvcq70008qfhxg   []  625.0     NaN           NaN         NaN
# 374  cmzzea13r3vg008wgqp0   []  625.0     NaN           NaN         NaN
# 381  cmzzfjedaqbg008skc30   []  625.0     NaN           NaN         NaN
# 382  cmzzfqp3r3vg008wgr0g   []  625.0     NaN           NaN         NaN
# 389  cmzzh3wvayrg008cq33g   []  625.0     NaN           NaN         NaN
# 390  cmzzh9nvcq70008qfje0   []  625.0     NaN           NaN         NaN
# 395  cmzzykjvcq70008qfk6g   []  625.0     NaN           NaN         NaN
# 396  cmzzysvvayrg008cq460   []  625.0     NaN           NaN         NaN
# 403  cn0009hvcq70008qfkg0   []  625.0     NaN           NaN         NaN
# 404  cn000gjvcq70008qfkgg   []  625.0     NaN           NaN         NaN
# 411  cn0023rrmwhg008fe450   []  625.0     NaN           NaN         NaN
# 412  cn002ahvayrg008cq4rg   []  625.0     NaN           NaN         NaN
# 419  cn0043g3r3vg008wgszg   []  625.0     NaN           NaN         NaN
# 420  cn004b1daqbg008ske40   []  625.0     NaN           NaN         NaN
# 427  cn00638daqbg008ske70   []  625.0     NaN           NaN         NaN
# 428  cn006asvayrg008cq4y0   []  625.0     NaN           NaN         NaN
#
#           job_status extra  optimization_level                   code  \
# 301   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 302   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 310   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 309   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 317   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 318   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 325   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 326   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 333   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 334   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 341   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 342   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 349   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 350   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 363   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 357   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 358   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 362   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 365   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 366   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 373   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 374   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 381  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 382  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 389  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 390  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 395  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 396  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 403  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 404  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 411  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 412  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 419  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 420  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 427  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
# 428  JobStatus.ERROR   NaN                 NaN  RepetitionCodeCircuit
#
#      distance rounds logical        layout                        descr
# 301      40.0     20       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 302      40.0     20       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 310      40.0     22       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 309      40.0     22       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 317      40.0     24       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 318      40.0     24       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 325      40.0     26       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 326      40.0     26       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 333      40.0     28       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 334      40.0     28       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 341      40.0     30       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 342      40.0     30       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 349      40.0     32       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 350      40.0     32       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 363      40.0     34       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 357      40.0     34       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 358      40.0     34       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 362      40.0     34       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 365      40.0     34       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 366      40.0     34       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 373      40.0     36       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 374      40.0     36       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 381      40.0     38       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 382      40.0     38       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 389      40.0     40       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 390      40.0     40       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 395      40.0     40       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 396      40.0     40       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 403      40.0     42       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 404      40.0     42       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 411      40.0     44       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 412      40.0     44       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 419      40.0     46       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 420      40.0     46       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 427      40.0     48       0  _is_hex=True  dist_55 INTERNAL ERROR TEST
# 428      40.0     48       1  _is_hex=True  dist_55 INTERNAL ERROR TEST
