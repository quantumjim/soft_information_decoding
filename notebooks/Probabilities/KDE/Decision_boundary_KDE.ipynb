# %%
# %load_ext autoreload
# %autoreload 2

# %%
from result_saver import SaverProvider
provider = SaverProvider()

# %% [markdown]
# # Import KDE

# %%
from soft_info import get_KDEs

device = 'ibmq_mumbai'

#KDEs, scalar = get_KDEs(provider, device, qubits=list(range(1, 27)))
KDEs, scaler = get_KDEs(provider, device, qubits=[0, 1, 2, 3, 4, 5, 6], plot=False, plot_db=True)

# %%
from soft_info import get_KDEs

device = 'ibmq_mumbai'

#KDEs, scalar = get_KDEs(provider, device, qubits=list(range(1, 27)))
KDEs, scaler = get_KDEs(provider, device, qubits=[0, 1, 2, 3, 4, 5, 6], plot=False, plot_db=True)
