# %% [markdown]
# # Initialization

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from result_saver import SaverProvider

provider = SaverProvider()

# %% [markdown]
# # Initialize simulator

# %%
from soft_info import RepCodeIQSimulator

DEVICE = 'ibm_sherbrooke'
DISTANCE = 11
ROUNDS = 11
OTHER_DATE = '2024-03-23'
_RESETS = False
LOGICAL = 0 # NOT NEEDED FOR EXTREME IQ BCS HARDCODED 0

_is_hex = True
if DEVICE == 'ibmq_mumbai':
    _is_hex = False

# Initialize simulator
simulator = RepCodeIQSimulator(provider, DISTANCE, ROUNDS, DEVICE, _is_hex=_is_hex, _resets = _RESETS, other_date=OTHER_DATE)
# Out:
# Found jobs for backend ibm_sherbrooke with closest execution date 2024-03-23 09:05:05.295665+00:00.

# %% [markdown]
# # Get IQ data

# %%
SHOTS = int(1e2)
NOISE_LIST = [3e-2, 0.8e-2, 1e-2, 3e-2] # [two-qubit-fidelity, reset error, measurement error, idle error]
# NOISE_LIST = None

IQ_data= simulator.generate_IQ(SHOTS, noise_list=NOISE_LIST)

# %% [markdown]
# # Decode IQ data

# %%
import numpy as np
import cpp_soft_info
from Scratch import load_calibration_memory

relError = 1
num_points = 51

bandwidths = np.linspace(0.1, 0.5, 20)

bandwidths = [0.2]

all_memories = load_calibration_memory(provider, tobecalib_backend=DEVICE, other_date=OTHER_DATE)
kde_dict = cpp_soft_info.get_KDEs(all_memories, bandwidths, relError=relError, absError=-1, num_points=num_points)
# Out:
# Found jobs for backend ibm_sherbrooke with closest execution date 2024-03-23 09:05:05.295665+00:00.

# %% [markdown]
# # Convertor decoding

# %%
from soft_info import inv_qubit_mapping
invert_qubit_mapping = inv_qubit_mapping(simulator.qubit_mapping)

# %%
pSoft, countMat = cpp_soft_info.iqConvertor(IQ_data, invert_qubit_mapping, kde_dict, relError, -1)

# %%
print(np.mean(pSoft))
# Out:
# 0.02588702577960091

# %% [markdown]
# # Stim decoding

# %%
from soft_info import RepetitionCodeStimCircuit

XBASIS = False
NOISE_LIST_2 = [3e-2, 1e-3, 1e-2, 3e-2, 3e-2, 0.5e-2, 0.5e-2]
SUBSAMPLING = False

code = RepetitionCodeStimCircuit(DISTANCE, ROUNDS, XBASIS, _RESETS, NOISE_LIST_2)
stim_circ = code.circuits[str(LOGICAL)]

# %%
result = cpp_soft_info.decodeStimSoft(stim_circ, countMat, pSoft, ROUNDS, int(LOGICAL), _RESETS, False)
print("num_errors KDE:", result.num_errors, "out of", len(IQ_data), "shots for _RESETS =", _RESETS)
# Out:
# Timings for shot 0 (seconds):
# 	Copying: num_errors KDE: 0 out of 100 shots for _RESETS = False
# 6.15e-05
# 	Softening: 0.000324292
# 	Error Model Creation: 0.00553662
# 	Matching Graph Creation: 0.000536875
# 	Det Syndromes: 3.7084e-05
# 	Detection Events: 3.6667e-05
# 	Decoding: 9.1583e-05
# 	Saving: 0
# Timings for shot 1 (seconds):
# 	Copying: 2.8417e-05
# 	Softening: 0.000276375
# 	Error Model Creation: 0.00528825
# 	Matching Graph Creation: 0.000488167
# 	Det Syndromes: 3.2e-05
# 	Detection Events: 4.25e-06
# 	Decoding: 7.5875e-05
# 	Saving: 0
# Timings for shot 2 (seconds):
# 	Copying: 2.6333e-05
# 	Softening: 0.000267125
# 	Error Model Creation: 0.00509671
# 	Matching Graph Creation: 0.000481125
# 	Det Syndromes: 2.9917e-05
# 	Detection Events: 3.792e-06
# 	Decoding: 8.0916e-05
# 	Saving: 4.2e-08
# Timings for shot 3 (seconds):
# 	Copying: 2.1333e-05
# 	Softening: 0.00025725
# 	Error Model Creation: 0.00547071
# 	Matching Graph Creation: 0.000517292
# 	Det Syndromes: 4.2459e-05
# 	Detection Events: 5.375e-06
# 	Decoding: 8.825e-05
# 	Saving: 4.1e-08
# Timings for shot 4 (seconds):
# 	Copying: 2.9917e-05
# 	Softening: 0.000284
# 	Error Model Creation: 0.00548146
# 	Matching Graph Creation: 0.000570625
# 	Det Syndromes: 3.3583e-05
# 	Detection Events: 3.625e-06
# 	Decoding: 8.125e-05
# 	Saving: 0
# Timings for shot 5 (seconds):
# 	Copying: 2.4167e-05
# 	Softening: 0.000268792
# 	Error Model Creation: 0.00552092
# 	Matching Graph Creation: 0.000494708
# 	Det Syndromes: 3.2792e-05
# 	Detection Events: 4.833e-06
# 	Decoding: 7.7e-05
# 	Saving: 4.2e-08
# Timings for shot 6 (seconds):
# 	Copying: 2.5292e-05
# 	Softening: 0.000265917
# 	Error Model Creation: 0.00527883
# 	Matching Graph Creation: 0.00047975
# 	Det Syndromes: 3.3458e-05
# 	Detection Events: 3.375e-06
# 	Decoding: 6.7667e-05
# 	Saving: 0
# Timings for shot 7 (seconds):
# 	Copying: 2.3542e-05
# 	Softening: 0.000264292
# 	Error Model Creation: 0.00510125
# 	Matching Graph Creation: 0.0006435
# 	Det Syndromes: 3.85e-05
# 	Detection Events: 6.375e-06
# 	Decoding: 0.00013525
# 	Saving: 4.2e-08
# Timings for shot 8 (seconds):
# 	Copying: 3.125e-05
# 	Softening: 0.000279542
# 	Error Model Creation: 0.00525312
# 	Matching Graph Creation: 0.000482042
# 	Det Syndromes: 3.075e-05
# 	Detection Events: 3.166e-06
# 	Decoding: 7.025e-05
# 	Saving: 4.2e-08
# Timings for shot 9 (seconds):
# 	Copying: 2.2583e-05
# 	Softening: 0.000259292
# 	Error Model Creation: 0.0054275
# 	Matching Graph Creation: 0.000480666
# 	Det Syndromes: 3.1833e-05
# 	Detection Events: 5.208e-06
# 	Decoding: 8.1459e-05
# 	Saving: 0
# Timings for shot 10 (seconds):
# 	Copying: 2.2125e-05
# 	Softening: 0.000263625
# 	Error Model Creation: 0.00509533
# 	Matching Graph Creation: 0.000475083
# 	Det Syndromes: 3.0208e-05
# 	Detection Events: 3.042e-06
# 	Decoding: 5.8542e-05
# 	Saving: 4.2e-08
# Timings for shot 11 (seconds):
# 	Copying: 2.1209e-05
# 	Softening: 0.000257625
# 	Error Model Creation: 0.00535012
# 	Matching Graph Creation: 0.000558333
# 	Det Syndromes: 3.9875e-05
# 	Detection Events: 7.584e-06
# 	Decoding: 0.000115333
# 	Saving: 0
# Timings for shot 12 (seconds):
# 	Copying: 3.5125e-05
# 	Softening: 0.000284042
# 	Error Model Creation: 0.005484
# 	Matching Graph Creation: 0.000772917
# 	Det Syndromes: 3.4166e-05
# 	Detection Events: 4.083e-06
# 	Decoding: 7.7709e-05
# 	Saving: 4.2e-08
# Timings for shot 13 (seconds):
# 	Copying: 2.5209e-05
# 	Softening: 0.00027075
# 	Error Model Creation: 0.00522587
# 	Matching Graph Creation: 0.000500334
# 	Det Syndromes: 3.3167e-05
# 	Detection Events: 4.5e-06
# 	Decoding: 7.0167e-05
# 	Saving: 0
# Timings for shot 14 (seconds):
# 	Copying: 2.3e-05
# 	Softening: 0.0002645
# 	Error Model Creation: 0.0057415
# 	Matching Graph Creation: 0.000520625
# 	Det Syndromes: 3.5583e-05
# 	Detection Events: 5.041e-06
# 	Decoding: 7.4709e-05
# 	Saving: 4.1e-08
# Timings for shot 15 (seconds):
# 	Copying: 2.7333e-05
# 	Softening: 0.000274042
# 	Error Model Creation: 0.00519688
# 	Matching Graph Creation: 0.000517375
# 	Det Syndromes: 5.1833e-05
# 	Detection Events: 9.583e-06
# 	Decoding: 0.000110292
# 	Saving: 4.2e-08
# Timings for shot 16 (seconds):
# 	Copying: 2.7542e-05
# 	Softening: 0.000285083
# 	Error Model Creation: 0.005314
# 	Matching Graph Creation: 0.000483042
# 	Det Syndromes: 3.1584e-05
# 	Detection Events: 4.166e-06
# 	Decoding: 7.4833e-05
# 	Saving: 4.2e-08
# Timings for shot 17 (seconds):
# 	Copying: 2.425e-05
# 	Softening: 0.00026575
# 	Error Model Creation: 0.00552283
# 	Matching Graph Creation: 0.00048875
# 	Det Syndromes: 3.575e-05
# 	Detection Events: 5.75e-06
# 	Decoding: 8.1709e-05
# 	Saving: 4.1e-08
# Timings for shot 18 (seconds):
# 	Copying: 2.5834e-05
# 	Softening: 0.000272875
# 	Error Model Creation: 0.00566492
# 	Matching Graph Creation: 0.000565791
# 	Det Syndromes: 3.6667e-05
# 	Detection Events: 5.334e-06
# 	Decoding: 0.000117833
# 	Saving: 4.1e-08
# Timings for shot 19 (seconds):
# 	Copying: 2.6209e-05
# 	Softening: 0.000270541
# 	Error Model Creation: 0.00512537
# 	Matching Graph Creation: 0.000483084
# 	Det Syndromes: 3.2292e-05
# 	Detection Events: 4.625e-06
# 	Decoding: 6.8084e-05
# 	Saving: 4.1e-08
# Timings for shot 20 (seconds):
# 	Copying: 2.1541e-05
# 	Softening: 0.000361542
# 	Error Model Creation: 0.00558767
# 	Matching Graph Creation: 0.000583083
# 	Det Syndromes: 3.25e-05
# 	Detection Events: 4.208e-06
# 	Decoding: 8.2667e-05
# 	Saving: 4.1e-08
# Timings for shot 21 (seconds):
# 	Copying: 2.2542e-05
# 	Softening: 0.000265416
# 	Error Model Creation: 0.005183
# 	Matching Graph Creation: 0.000492833
# 	Det Syndromes: 3.15e-05
# 	Detection Events: 4.166e-06
# 	Decoding: 6.6333e-05
# 	Saving: 0
# Timings for shot 22 (seconds):
# 	Copying: 2.2916e-05
# 	Softening: 0.000263875
# 	Error Model Creation: 0.00551808
# 	Matching Graph Creation: 0.000484666
# 	Det Syndromes: 3.0208e-05
# 	Detection Events: 3.583e-06
# 	Decoding: 6.3917e-05
# 	Saving: 0
# Timings for shot 23 (seconds):
# 	Copying: 2.2083e-05
# 	Softening: 0.000259458
# 	Error Model Creation: 0.00533612
# 	Matching Graph Creation: 0.0004955
# 	Det Syndromes: 4.2958e-05
# 	Detection Events: 4.792e-06
# 	Decoding: 8.1916e-05
# 	Saving: 4.2e-08
# Timings for shot 24 (seconds):
# 	Copying: 2.9042e-05
# 	Softening: 0.000280583
# 	Error Model Creation: 0.00522475
# 	Matching Graph Creation: 0.000474709
# 	Det Syndromes: 3.0125e-05
# 	Detection Events: 3.792e-06
# 	Decoding: 7.8333e-05
# 	Saving: 0
# Timings for shot 25 (seconds):
# 	Copying: 2.1833e-05
# 	Softening: 0.000257791
# 	Error Model Creation: 0.00528796
# 	Matching Graph Creation: 0.000512084
# 	Det Syndromes: 3.4791e-05
# 	Detection Events: 7.125e-06
# 	Decoding: 8.8958e-05
# 	Saving: 4.2e-08
# Timings for shot 26 (seconds):
# 	Copying: 3.6042e-05
# 	Softening: 0.000287292
# 	Error Model Creation: 0.00531667
# 	Matching Graph Creation: 0.0005395
# 	Det Syndromes: 3.95e-05
# 	Detection Events: 5.083e-06
# 	Decoding: 8.2041e-05
# 	Saving: 0
# Timings for shot 27 (seconds):
# 	Copying: 2.65e-05
# 	Softening: 0.000283417
# 	Error Model Creation: 0.00537629
# 	Matching Graph Creation: 0.000474125
# 	Det Syndromes: 3.0875e-05
# 	Detection Events: 3.833e-06
# 	Decoding: 7.3e-05
# 	Saving: 4.2e-08
# Timings for shot 28 (seconds):
# 	Copying: 2.2375e-05
# 	Softening: 0.000256916
# 	Error Model Creation: 0.00535271
# 	Matching Graph Creation: 0.000557834
# 	Det Syndromes: 3.6583e-05
# 	Detection Events: 5.792e-06
# 	Decoding: 0.000104541
# 	Saving: 0
# Timings for shot 29 (seconds):
# 	Copying: 2.925e-05
# 	Softening: 0.00028575
# 	Error Model Creation: 0.0051925
# 	Matching Graph Creation: 0.000485833
# 	Det Syndromes: 3.1e-05
# 	Detection Events: 3.584e-06
# 	Decoding: 7.0292e-05
# 	Saving: 0
# Timings for shot 30 (seconds):
# 	Copying: 2.2541e-05
# 	Softening: 0.000262667
# 	Error Model Creation: 0.00521592
# 	Matching Graph Creation: 0.000486
# 	Det Syndromes: 3.0083e-05
# 	Detection Events: 3.667e-06
# 	Decoding: 7.0666e-05
# 	Saving: 0
# Timings for shot 31 (seconds):
# 	Copying: 2.125e-05
# 	Softening: 0.000257833
# 	Error Model Creation: 0.00520942
# 	Matching Graph Creation: 0.000515709
# 	Det Syndromes: 3.5875e-05
# 	Detection Events: 6.584e-06
# 	Decoding: 0.000114458
# 	Saving: 4.1e-08
# Timings for shot 32 (seconds):
# 	Copying: 3.075e-05
# 	Softening: 0.00027375
# 	Error Model Creation: 0.00518846
# 	Matching Graph Creation: 0.000508375
# 	Det Syndromes: 3.2916e-05
# 	Detection Events: 4.917e-06
# 	Decoding: 8.4292e-05
# 	Saving: 4.2e-08
# Timings for shot 33 (seconds):
# 	Copying: 2.425e-05
# 	Softening: 0.000269417
# 	Error Model Creation: 0.00534921
# 	Matching Graph Creation: 0.00050825
# 	Det Syndromes: 3.3708e-05
# 	Detection Events: 4.625e-06
# 	Decoding: 7.775e-05
# 	Saving: 0
# Timings for shot 34 (seconds):
# 	Copying: 2.6958e-05
# 	Softening: 0.000279375
# 	Error Model Creation: 0.00530975
# 	Matching Graph Creation: 0.000497292
# 	Det Syndromes: 3.2e-05
# 	Detection Events: 4.167e-06
# 	Decoding: 7.5834e-05
# 	Saving: 4.1e-08
# Timings for shot 35 (seconds):
# 	Copying: 2.3166e-05
# 	Softening: 0.000260958
# 	Error Model Creation: 0.00524246
# 	Matching Graph Creation: 0.000472
# 	Det Syndromes: 4.1334e-05
# 	Detection Events: 4.833e-06
# 	Decoding: 7.175e-05
# 	Saving: 4.2e-08
# Timings for shot 36 (seconds):
# 	Copying: 3.0209e-05
# 	Softening: 0.000274458
# 	Error Model Creation: 0.00510562
# 	Matching Graph Creation: 0.000492125
# 	Det Syndromes: 3.1875e-05
# 	Detection Events: 4.125e-06
# 	Decoding: 7.2666e-05
# 	Saving: 0
# Timings for shot 37 (seconds):
# 	Copying: 2.2834e-05
# 	Softening: 0.000269208
# 	Error Model Creation: 0.00545946
# 	Matching Graph Creation: 0.000498625
# 	Det Syndromes: 3.4417e-05
# 	Detection Events: 4.75e-06
# 	Decoding: 8.1709e-05
# 	Saving: 4.1e-08
# Timings for shot 38 (seconds):
# 	Copying: 2.3166e-05
# 	Softening: 0.000279709
# 	Error Model Creation: 0.00520525
# 	Matching Graph Creation: 0.000516125
# 	Det Syndromes: 4.2083e-05
# 	Detection Events: 8.709e-06
# 	Decoding: 9.4041e-05
# 	Saving: 0
# Timings for shot 39 (seconds):
# 	Copying: 2.9959e-05
# 	Softening: 0.000277042
# 	Error Model Creation: 0.00519696
# 	Matching Graph Creation: 0.00049025
# 	Det Syndromes: 3.0708e-05
# 	Detection Events: 3.917e-06
# 	Decoding: 8.0791e-05
# 	Saving: 0
# Timings for shot 40 (seconds):
# 	Copying: 2.4583e-05
# 	Softening: 0.000267625
# 	Error Model Creation: 0.00525321
# 	Matching Graph Creation: 0.000506125
# 	Det Syndromes: 3.4292e-05
# 	Detection Events: 3.958e-06
# 	Decoding: 8.3041e-05
# 	Saving: 4.2e-08
# Timings for shot 41 (seconds):
# 	Copying: 2.2208e-05
# 	Softening: 0.000266125
# 	Error Model Creation: 0.00518238
# 	Matching Graph Creation: 0.000491791
# 	Det Syndromes: 3.0375e-05
# 	Detection Events: 3.791e-06
# 	Decoding: 8.4542e-05
# 	Saving: 0
# Timings for shot 42 (seconds):
# 	Copying: 2.1583e-05
# 	Softening: 0.000260375
# 	Error Model Creation: 0.00510987
# 	Matching Graph Creation: 0.000489292
# 	Det Syndromes: 3.575e-05
# 	Detection Events: 3.75e-06
# 	Decoding: 0.000113042
# 	Saving: 4.2e-08
# Timings for shot 43 (seconds):
# 	Copying: 2.8833e-05
# 	Softening: 0.000270125
# 	Error Model Creation: 0.00520383
# 	Matching Graph Creation: 0.00048975
# 	Det Syndromes: 3.1375e-05
# 	Detection Events: 3.041e-06
# 	Decoding: 6.5375e-05
# 	Saving: 4.2e-08
# Timings for shot 44 (seconds):
# 	Copying: 2.1583e-05
# 	Softening: 0.000262917
# 	Error Model Creation: 0.00533962
# 	Matching Graph Creation: 0.000532375
# 	Det Syndromes: 3.2042e-05
# 	Detection Events: 4.083e-06
# 	Decoding: 0.000102833
# 	Saving: 0
# Timings for shot 45 (seconds):
# 	Copying: 2.4708e-05
# 	Softening: 0.000347875
# 	Error Model Creation: 0.00507846
# 	Matching Graph Creation: 0.000495958
# 	Det Syndromes: 4.5833e-05
# 	Detection Events: 4e-06
# 	Decoding: 6.5625e-05
# 	Saving: 0
# Timings for shot 46 (seconds):
# 	Copying: 3.0959e-05
# 	Softening: 0.000260292
# 	Error Model Creation: 0.00520129
# 	Matching Graph Creation: 0.000500292
# 	Det Syndromes: 3.2e-05
# 	Detection Events: 3.375e-06
# 	Decoding: 7.5542e-05
# 	Saving: 0
# Timings for shot 47 (seconds):
# 	Copying: 2.2792e-05
# 	Softening: 0.000306166
# 	Error Model Creation: 0.00514246
# 	Matching Graph Creation: 0.00049375
# 	Det Syndromes: 2.9875e-05
# 	Detection Events: 3.459e-06
# 	Decoding: 7.875e-05
# 	Saving: 0
# Timings for shot 48 (seconds):
# 	Copying: 2.5917e-05
# 	Softening: 0.000281166
# 	Error Model Creation: 0.00515717
# 	Matching Graph Creation: 0.00052925
# 	Det Syndromes: 3.2583e-05
# 	Detection Events: 3.125e-06
# 	Decoding: 8.4083e-05
# 	Saving: 0
# Timings for shot 49 (seconds):
# 	Copying: 2.3416e-05
# 	Softening: 0.000264375
# 	Error Model Creation: 0.0051705
# 	Matching Graph Creation: 0.000488666
# 	Det Syndromes: 2.9459e-05
# 	Detection Events: 3.542e-06
# 	Decoding: 6.8791e-05
# 	Saving: 4.2e-08
# Timings for shot 50 (seconds):
# 	Copying: 2.1375e-05
# 	Softening: 0.000259042
# 	Error Model Creation: 0.00512571
# 	Matching Graph Creation: 0.000482708
# 	Det Syndromes: 2.9416e-05
# 	Detection Events: 3.459e-06
# 	Decoding: 7.3833e-05
# 	Saving: 4.1e-08
# Timings for shot 51 (seconds):
# 	Copying: 2.0625e-05
# 	Softening: 0.000259792
# 	Error Model Creation: 0.00517975
# 	Matching Graph Creation: 0.000499834
# 	Det Syndromes: 3.3916e-05
# 	Detection Events: 4.042e-06
# 	Decoding: 7.8375e-05
# 	Saving: 4.1e-08
# Timings for shot 52 (seconds):
# 	Copying: 2.9666e-05
# 	Softening: 0.000276209
# 	Error Model Creation: 0.00520787
# 	Matching Graph Creation: 0.000490375
# 	Det Syndromes: 2.9666e-05
# 	Detection Events: 3.417e-06
# 	Decoding: 7.4833e-05
# 	Saving: 0
# Timings for shot 53 (seconds):
# 	Copying: 2.3791e-05
# 	Softening: 0.000262125
# 	Error Model Creation: 0.00522388
# 	Matching Graph Creation: 0.00048675
# 	Det Syndromes: 3.1208e-05
# 	Detection Events: 6.333e-06
# 	Decoding: 7.95e-05
# 	Saving: 4.1e-08
# Timings for shot 54 (seconds):
# 	Copying: 2.3e-05
# 	Softening: 0.000263041
# 	Error Model Creation: 0.00510817
# 	Matching Graph Creation: 0.000523625
# 	Det Syndromes: 3.15e-05
# 	Detection Events: 3.041e-06
# 	Decoding: 7.0875e-05
# 	Saving: 0
# Timings for shot 55 (seconds):
# 	Copying: 2.1917e-05
# 	Softening: 0.000262291
# 	Error Model Creation: 0.00510688
# 	Matching Graph Creation: 0.000485
# 	Det Syndromes: 3.0291e-05
# 	Detection Events: 3.584e-06
# 	Decoding: 9.2167e-05
# 	Saving: 0
# Timings for shot 56 (seconds):
# 	Copying: 2.0958e-05
# 	Softening: 0.000261458
# 	Error Model Creation: 0.00517771
# 	Matching Graph Creation: 0.000489958
# 	Det Syndromes: 3.2541e-05
# 	Detection Events: 3.5e-06
# 	Decoding: 7.5875e-05
# 	Saving: 4.2e-08
# Timings for shot 57 (seconds):
# 	Copying: 2.3042e-05
# 	Softening: 0.000268459
# 	Error Model Creation: 0.00518358
# 	Matching Graph Creation: 0.000483209
# 	Det Syndromes: 3.0417e-05
# 	Detection Events: 2.875e-06
# 	Decoding: 6.9666e-05
# 	Saving: 0
# Timings for shot 58 (seconds):
# 	Copying: 2.3625e-05
# 	Softening: 0.000255667
# 	Error Model Creation: 0.00522396
# 	Matching Graph Creation: 0.000486125
# 	Det Syndromes: 3.1709e-05
# 	Detection Events: 3.917e-06
# 	Decoding: 7.6333e-05
# 	Saving: 4.2e-08
# Timings for shot 59 (seconds):
# 	Copying: 2.3209e-05
# 	Softening: 0.000269
# 	Error Model Creation: 0.00520254
# 	Matching Graph Creation: 0.000493792
# 	Det Syndromes: 3.2416e-05
# 	Detection Events: 4.667e-06
# 	Decoding: 8.2166e-05
# 	Saving: 4.1e-08
# Timings for shot 60 (seconds):
# 	Copying: 2.4958e-05
# 	Softening: 0.000271667
# 	Error Model Creation: 0.00526292
# 	Matching Graph Creation: 0.00049325
# 	Det Syndromes: 3.0208e-05
# 	Detection Events: 3.875e-06
# 	Decoding: 7.2625e-05
# 	Saving: 0
# Timings for shot 61 (seconds):
# 	Copying: 2.1833e-05
# 	Softening: 0.000267542
# 	Error Model Creation: 0.00526817
# 	Matching Graph Creation: 0.000493209
# 	Det Syndromes: 3.0875e-05
# 	Detection Events: 3.667e-06
# 	Decoding: 7.2958e-05
# 	Saving: 0
# Timings for shot 62 (seconds):
# 	Copying: 2.3334e-05
# 	Softening: 0.0002725
# 	Error Model Creation: 0.00525521
# 	Matching Graph Creation: 0.000498916
# 	Det Syndromes: 3.0958e-05
# 	Detection Events: 4e-06
# 	Decoding: 8.1417e-05
# 	Saving: 0
# Timings for shot 63 (seconds):
# 	Copying: 2.2334e-05
# 	Softening: 0.000270208
# 	Error Model Creation: 0.00510733
# 	Matching Graph Creation: 0.00048975
# 	Det Syndromes: 2.95e-05
# 	Detection Events: 3.75e-06
# 	Decoding: 8.6292e-05
# 	Saving: 4.2e-08
# Timings for shot 64 (seconds):
# 	Copying: 2.1e-05
# 	Softening: 0.000260667
# 	Error Model Creation: 0.00518079
# 	Matching Graph Creation: 0.000487209
# 	Det Syndromes: 3.0208e-05
# 	Detection Events: 3.5e-06
# 	Decoding: 6.9167e-05
# 	Saving: 0
# Timings for shot 65 (seconds):
# 	Copying: 2.1667e-05
# 	Softening: 0.000265417
# 	Error Model Creation: 0.00512042
# 	Matching Graph Creation: 0.000486083
# 	Det Syndromes: 2.9834e-05
# 	Detection Events: 3.584e-06
# 	Decoding: 7.9125e-05
# 	Saving: 0
# Timings for shot 66 (seconds):
# 	Copying: 2.1042e-05
# 	Softening: 0.000261042
# 	Error Model Creation: 0.00511521
# 	Matching Graph Creation: 0.000492625
# 	Det Syndromes: 2.9458e-05
# 	Detection Events: 2.709e-06
# 	Decoding: 6.9208e-05
# 	Saving: 0
# Timings for shot 67 (seconds):
# 	Copying: 2.1333e-05
# 	Softening: 0.000258375
# 	Error Model Creation: 0.00521458
# 	Matching Graph Creation: 0.000499125
# 	Det Syndromes: 3.1375e-05
# 	Detection Events: 4.584e-06
# 	Decoding: 7.9334e-05
# 	Saving: 4.2e-08
# Timings for shot 68 (seconds):
# 	Copying: 2.4209e-05
# 	Softening: 0.000267291
# 	Error Model Creation: 0.00520758
# 	Matching Graph Creation: 0.000511875
# 	Det Syndromes: 3.1292e-05
# 	Detection Events: 4.166e-06
# 	Decoding: 8.0459e-05
# 	Saving: 0
# Timings for shot 69 (seconds):
# 	Copying: 2.2584e-05
# 	Softening: 0.000274291
# 	Error Model Creation: 0.00519875
# 	Matching Graph Creation: 0.00050075
# 	Det Syndromes: 3.1167e-05
# 	Detection Events: 3.75e-06
# 	Decoding: 7.3792e-05
# 	Saving: 4.1e-08
# Timings for shot 70 (seconds):
# 	Copying: 2.2291e-05
# 	Softening: 0.000266209
# 	Error Model Creation: 0.00518896
# 	Matching Graph Creation: 0.00049675
# 	Det Syndromes: 3.1333e-05
# 	Detection Events: 3.917e-06
# 	Decoding: 7.5333e-05
# 	Saving: 4.1e-08
# Timings for shot 71 (seconds):
# 	Copying: 2.3083e-05
# 	Softening: 0.000333875
# 	Error Model Creation: 0.00534842
# 	Matching Graph Creation: 0.000475125
# 	Det Syndromes: 3.2542e-05
# 	Detection Events: 4.25e-06
# 	Decoding: 6.9375e-05
# 	Saving: 0
# Timings for shot 72 (seconds):
# 	Copying: 2.6209e-05
# 	Softening: 0.000261
# 	Error Model Creation: 0.00510658
# 	Matching Graph Creation: 0.000482
# 	Det Syndromes: 3.0375e-05
# 	Detection Events: 3.791e-06
# 	Decoding: 6.7584e-05
# 	Saving: 4.1e-08
# Timings for shot 73 (seconds):
# 	Copying: 2.2667e-05
# 	Softening: 0.000270917
# 	Error Model Creation: 0.00515879
# 	Matching Graph Creation: 0.000486375
# 	Det Syndromes: 3.0666e-05
# 	Detection Events: 3.583e-06
# 	Decoding: 6.2458e-05
# 	Saving: 4.2e-08
# Timings for shot 74 (seconds):
# 	Copying: 2.1167e-05
# 	Softening: 0.000261208
# 	Error Model Creation: 0.00534204
# 	Matching Graph Creation: 0.00051325
# 	Det Syndromes: 3.8625e-05
# 	Detection Events: 5.292e-06
# 	Decoding: 8.0291e-05
# 	Saving: 0
# Timings for shot 75 (seconds):
# 	Copying: 2.6458e-05
# 	Softening: 0.000282125
# 	Error Model Creation: 0.00530867
# 	Matching Graph Creation: 0.00050175
# 	Det Syndromes: 3.95e-05
# 	Detection Events: 4.125e-06
# 	Decoding: 8.95e-05
# 	Saving: 4.1e-08
# Timings for shot 76 (seconds):
# 	Copying: 2.6166e-05
# 	Softening: 0.000279459
# 	Error Model Creation: 0.00531021
# 	Matching Graph Creation: 0.000494
# 	Det Syndromes: 3.325e-05
# 	Detection Events: 4.583e-06
# 	Decoding: 7.8375e-05
# 	Saving: 4.1e-08
# Timings for shot 77 (seconds):
# 	Copying: 2.3084e-05
# 	Softening: 0.000270334
# 	Error Model Creation: 0.00521958
# 	Matching Graph Creation: 0.00049
# 	Det Syndromes: 3.0792e-05
# 	Detection Events: 3.708e-06
# 	Decoding: 6.6916e-05
# 	Saving: 0
# Timings for shot 78 (seconds):
# 	Copying: 2.1167e-05
# 	Softening: 0.000264667
# 	Error Model Creation: 0.00514108
# 	Matching Graph Creation: 0.000480625
# 	Det Syndromes: 3.0459e-05
# 	Detection Events: 3.833e-06
# 	Decoding: 6.6083e-05
# 	Saving: 0
# Timings for shot 79 (seconds):
# 	Copying: 2.2208e-05
# 	Softening: 0.000264375
# 	Error Model Creation: 0.00518192
# 	Matching Graph Creation: 0.000486917
# 	Det Syndromes: 2.9792e-05
# 	Detection Events: 3.833e-06
# 	Decoding: 6.925e-05
# 	Saving: 0
# Timings for shot 80 (seconds):
# 	Copying: 2.1958e-05
# 	Softening: 0.000263667
# 	Error Model Creation: 0.00512604
# 	Matching Graph Creation: 0.000510708
# 	Det Syndromes: 3.1542e-05
# 	Detection Events: 4e-06
# 	Decoding: 9.325e-05
# 	Saving: 4.2e-08
# Timings for shot 81 (seconds):
# 	Copying: 2.6291e-05
# 	Softening: 0.000264959
# 	Error Model Creation: 0.00523104
# 	Matching Graph Creation: 0.000503375
# 	Det Syndromes: 3.2333e-05
# 	Detection Events: 4.709e-06
# 	Decoding: 8.2625e-05
# 	Saving: 0
# Timings for shot 82 (seconds):
# 	Copying: 2.4167e-05
# 	Softening: 0.000273917
# 	Error Model Creation: 0.00520704
# 	Matching Graph Creation: 0.0004835
# 	Det Syndromes: 3.0125e-05
# 	Detection Events: 2.917e-06
# 	Decoding: 6.725e-05
# 	Saving: 4.2e-08
# Timings for shot 83 (seconds):
# 	Copying: 2.175e-05
# 	Softening: 0.000258416
# 	Error Model Creation: 0.00519963
# 	Matching Graph Creation: 0.000484917
# 	Det Syndromes: 3.025e-05
# 	Detection Events: 3.792e-06
# 	Decoding: 8.7792e-05
# 	Saving: 0
# Timings for shot 84 (seconds):
# 	Copying: 2.2084e-05
# 	Softening: 0.000260958
# 	Error Model Creation: 0.00513975
# 	Matching Graph Creation: 0.00050425
# 	Det Syndromes: 3.1208e-05
# 	Detection Events: 3.834e-06
# 	Decoding: 7.5125e-05
# 	Saving: 0
# Timings for shot 85 (seconds):
# 	Copying: 3.675e-05
# 	Softening: 0.000275083
# 	Error Model Creation: 0.00512558
# 	Matching Graph Creation: 0.000492458
# 	Det Syndromes: 3.2292e-05
# 	Detection Events: 2.833e-06
# 	Decoding: 6.6625e-05
# 	Saving: 4.1e-08
# Timings for shot 86 (seconds):
# 	Copying: 2.2459e-05
# 	Softening: 0.000261
# 	Error Model Creation: 0.00517396
# 	Matching Graph Creation: 0.000481458
# 	Det Syndromes: 2.9375e-05
# 	Detection Events: 3.667e-06
# 	Decoding: 7.225e-05
# 	Saving: 0
# Timings for shot 87 (seconds):
# 	Copying: 2.1417e-05
# 	Softening: 0.000260916
# 	Error Model Creation: 0.00518454
# 	Matching Graph Creation: 0.0004875
# 	Det Syndromes: 3.0417e-05
# 	Detection Events: 3.709e-06
# 	Decoding: 8.2e-05
# 	Saving: 0
# Timings for shot 88 (seconds):
# 	Copying: 2.1458e-05
# 	Softening: 0.000282958
# 	Error Model Creation: 0.00514346
# 	Matching Graph Creation: 0.000531209
# 	Det Syndromes: 2.9791e-05
# 	Detection Events: 3.583e-06
# 	Decoding: 6.4209e-05
# 	Saving: 4.1e-08
# Timings for shot 89 (seconds):
# 	Copying: 2.0959e-05
# 	Softening: 0.000262375
# 	Error Model Creation: 0.00512154
# 	Matching Graph Creation: 0.00048
# 	Det Syndromes: 3.1708e-05
# 	Detection Events: 3.458e-06
# 	Decoding: 6.1375e-05
# 	Saving: 0
# Timings for shot 90 (seconds):
# 	Copying: 2.0916e-05
# 	Softening: 0.0002555
# 	Error Model Creation: 0.00512667
# 	Matching Graph Creation: 0.000482334
# 	Det Syndromes: 2.9833e-05
# 	Detection Events: 3.5e-06
# 	Decoding: 6.9292e-05
# 	Saving: 4.2e-08
# Timings for shot 91 (seconds):
# 	Copying: 2.1709e-05
# 	Softening: 0.000259334
# 	Error Model Creation: 0.00515425
# 	Matching Graph Creation: 0.00048325
# 	Det Syndromes: 2.9791e-05
# 	Detection Events: 2.667e-06
# 	Decoding: 5.8041e-05
# 	Saving: 4.2e-08
# Timings for shot 92 (seconds):
# 	Copying: 2.0958e-05
# 	Softening: 0.000263375
# 	Error Model Creation: 0.00513208
# 	Matching Graph Creation: 0.00047875
# 	Det Syndromes: 2.975e-05
# 	Detection Events: 2.75e-06
# 	Decoding: 5.7917e-05
# 	Saving: 4.2e-08
# Timings for shot 93 (seconds):
# 	Copying: 2.0375e-05
# 	Softening: 0.000259709
# 	Error Model Creation: 0.00513088
# 	Matching Graph Creation: 0.000479708
# 	Det Syndromes: 2.9417e-05
# 	Detection Events: 4.667e-06
# 	Decoding: 6.6292e-05
# 	Saving: 4.1e-08
# Timings for shot 94 (seconds):
# 	Copying: 2.2e-05
# 	Softening: 0.000261334
# 	Error Model Creation: 0.00521588
# 	Matching Graph Creation: 0.000490084
# 	Det Syndromes: 3.0875e-05
# 	Detection Events: 3.458e-06
# 	Decoding: 8.1583e-05
# 	Saving: 4.2e-08
# Timings for shot 95 (seconds):
# 	Copying: 2.2167e-05
# 	Softening: 0.000258125
# 	Error Model Creation: 0.00517458
# 	Matching Graph Creation: 0.000486709
# 	Det Syndromes: 2.975e-05
# 	Detection Events: 2.875e-06
# 	Decoding: 6.8291e-05
# 	Saving: 4.2e-08
# Timings for shot 96 (seconds):
# 	Copying: 2.0916e-05
# 	Softening: 0.000259958
# 	Error Model Creation: 0.0051385
# 	Matching Graph Creation: 0.000488625
# 	Det Syndromes: 2.975e-05
# 	Detection Events: 3.625e-06
# 	Decoding: 7.4417e-05
# 	Saving: 0
# Timings for shot 97 (seconds):
# 	Copying: 2.1291e-05
# 	Softening: 0.000257
# 	Error Model Creation: 0.00522017
# 	Matching Graph Creation: 0.000488791
# 	Det Syndromes: 3.4375e-05
# 	Detection Events: 3.75e-06
# 	Decoding: 8.325e-05
# 	Saving: 4.1e-08
# Timings for shot 98 (seconds):
# 	Copying: 2.6708e-05
# 	Softening: 0.000272042
# 	Error Model Creation: 0.00519575
# 	Matching Graph Creation: 0.000522667
# 	Det Syndromes: 3.6042e-05
# 	Detection Events: 8.083e-06
# 	Decoding: 0.00010775
# 	Saving: 4.2e-08
# Timings for shot 99 (seconds):
# 	Copying: 2.3666e-05
# 	Softening: 0.000272792
# 	Error Model Creation: 0.00513312
# 	Matching Graph Creation: 0.000491375
# 	Det Syndromes: 3.0708e-05
# 	Detection Events: 2.25e-06
# 	Decoding: 7.175e-05
# 	Saving: 4.2e-08
# Total execution time (seconds): 0.623681

# %%
result = cpp_soft_info.decodeConvertorSoft(stim_circ.detector_error_model(), countMat, pSoft, ROUNDS, int(LOGICAL), _RESETS, False)

# %% [markdown]
# # Using cpp kde

# %%
import stim
import pymatching

# circ = simulator.stim_circ
circ = stim_circ 
model = circ.detector_error_model(decompose_errors=False)

# %%
_DETAILED = False

matching = pymatching.Matching.from_detector_error_model(model)
result = cpp_soft_info.decode_IQ_fast(model, IQ_data,
                                           ROUNDS, int(LOGICAL), _RESETS, simulator.qubit_mapping, simulator.grid_dict,
                                           simulator.processed_scaler_dict, _detailed=_DETAILED, nb_intervals=-1)

print("num_errors IQ:", result.num_errors, "out of", len(IQ_data), "shots for _RESETS =", _RESETS)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 5
#       1 _DETAILED = False
#       3 matching = pymatching.Matching.from_detector_error_model(model)
#       4 result = cpp_soft_info.decode_IQ_fast(model, IQ_data,
# ----> 5                                            ROUNDS, int(LOGICAL), _RESETS, simulator.qubit_mapping, simulator.grid_dict,
#       6                                            simulator.processed_scaler_dict, _detailed=_DETAILED, nb_intervals=-1)
#       8 print("num_errors IQ:", result.num_errors, "out of", len(IQ_data), "shots for _RESETS =", _RESETS)
#
# AttributeError: 'RepCodeIQSimulator' object has no attribute 'grid_dict'

# %%
_DETAILED = False

relError = 1
absError = -1

# relError = 1
# absError = 10

result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, ROUNDS, int(LOGICAL), _RESETS, 
                                         simulator.qubit_mapping, kde_dict, _DETAILED, relError=relError, absError=absError,
                                         nb_intervals=-1)

print("num_errors KDE:", result_kde.num_errors, "out of", len(IQ_data), "shots for _RESETS =", _RESETS)
# Out:
# num_errors KDE: 0 out of 100 shots for _RESETS = False

# %%
p_meas = -1
# p_meas = 7e-2 

result_informed = cpp_soft_info.decode_IQ_shots_flat_informed(model, IQ_data[:],
                                           ROUNDS, int(LOGICAL), _RESETS, simulator.qubit_mapping, simulator.grid_dict, simulator.processed_scaler_dict,
                                           p_data = -1, p_mixed = -1, p_meas = p_meas, common_measure=-1, _detailed=_DETAILED, _ntnn_edges = True)

print("num_errors informed:", result_informed.num_errors, "out of", len(IQ_data), "shots for _RESETS =", _RESETS)
         
# takes 1s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 5
#       1 p_meas = -1
#       2 # p_meas = 7e-2
#       4 result_informed = cpp_soft_info.decode_IQ_shots_flat_informed(model, IQ_data[:],
# ----> 5                                            ROUNDS, int(LOGICAL), _RESETS, simulator.qubit_mapping, simulator.grid_dict, simulator.processed_scaler_dict,
#       6                                            p_data = -1, p_mixed = -1, p_meas = p_meas, common_measure=-1, _detailed=_DETAILED, _ntnn_edges = True)
#       8 print("num_errors informed:", result_informed.num_errors, "out of", len(IQ_data), "shots for _RESETS =", _RESETS)
#      10 # takes 1s
#
# AttributeError: 'RepCodeIQSimulator' object has no attribute 'grid_dict'
