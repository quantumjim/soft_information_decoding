# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
from result_saver import SaverProvider
provider = SaverProvider()

# %%
from Scratch import metadata_loader
import numpy as np
from tqdm import tqdm

DEVICE = "ibm_sherbrooke"
LOGICAL = str(0)
XBASIS = True
ROUNDS = 100

state = "X" if XBASIS else "Z"
state += LOGICAL
print(f"state = {state}")


# Load the metadata
md = metadata_loader(True, True)
md = md[md["job_status"] == "JobStatus.DONE"]
md = md[md["code"] == "RepetitionCodeCircuit"]
md = md[md["descr"] == 'subset RepCodes']
md = md.dropna(subset=["rounds"])
md = md[md["meas_level"] == 1]
md['rounds'] = md['rounds'].astype(int)
md['distance'] = md['distance'].astype(int)

md = md[md["backend_name"] == DEVICE]
md = md[md["logical"] == LOGICAL]
md = md[md["xbasis"] == XBASIS]
md = md[md["rounds"] == ROUNDS]

# md = md[16:]
print("shape:", md.shape)
md
# Out:
# state = X0
# shape: (20, 18)
#                          creation_date             notebook_name  \
# 3854  2024-03-16 17:33:31.770000+01:00  Sherbrooke_RepCodes_jobs
# 3853  2024-03-16 17:33:17.132000+01:00  Sherbrooke_RepCodes_jobs
# 3852  2024-03-16 17:33:01.556000+01:00  Sherbrooke_RepCodes_jobs
# 3851  2024-03-16 17:32:19.082000+01:00  Sherbrooke_RepCodes_jobs
# 3850  2024-03-16 17:32:03.025000+01:00  Sherbrooke_RepCodes_jobs
# 3849  2024-03-16 17:31:47.290000+01:00  Sherbrooke_RepCodes_jobs
# 3848  2024-03-16 17:31:32.108000+01:00  Sherbrooke_RepCodes_jobs
# 3847  2024-03-16 17:31:15.424000+01:00  Sherbrooke_RepCodes_jobs
# 3846  2024-03-16 17:30:59.405000+01:00  Sherbrooke_RepCodes_jobs
# 3845  2024-03-16 17:30:44.039000+01:00  Sherbrooke_RepCodes_jobs
# 3844  2024-03-16 17:30:28.161000+01:00  Sherbrooke_RepCodes_jobs
# 3843  2024-03-16 17:30:12.144000+01:00  Sherbrooke_RepCodes_jobs
# 3842  2024-03-16 17:29:56.783000+01:00  Sherbrooke_RepCodes_jobs
# 3841  2024-03-16 17:29:41.851000+01:00  Sherbrooke_RepCodes_jobs
# 3840  2024-03-16 17:29:26.166000+01:00  Sherbrooke_RepCodes_jobs
# 3839  2024-03-16 17:29:09.021000+01:00  Sherbrooke_RepCodes_jobs
# 3838  2024-03-16 17:28:52.824000+01:00  Sherbrooke_RepCodes_jobs
# 3837  2024-03-16 17:28:36.670000+01:00  Sherbrooke_RepCodes_jobs
# 3836  2024-03-16 17:28:21.334000+01:00  Sherbrooke_RepCodes_jobs
# 3835  2024-03-16 17:28:06.410000+01:00  Sherbrooke_RepCodes_jobs
#
#         backend_name                job_id  \
# 3854  ibm_sherbrooke  cqtwkpy88ev000813d9g
# 3853  ibm_sherbrooke  cqtwkk64x0mg008acts0
# 3852  ibm_sherbrooke  cqtwkfd4x0mg008actrg
# 3851  ibm_sherbrooke  cqtwk4m88ev000813d90
# 3850  ibm_sherbrooke  cqtwk0m88ev000813d8g
# 3849  ibm_sherbrooke  cqtwjwv4x0mg008actng
# 3848  ibm_sherbrooke  cqtwjrv9nfw0008ht4rg
# 3847  ibm_sherbrooke  cqtwjmt36d60008j03dg
# 3846  ibm_sherbrooke  cqtwjgt9nfw0008ht4r0
# 3845  ibm_sherbrooke  cqtwjcs4x0mg008actmg
# 3844  ibm_sherbrooke  cqtwj8s9nfw0008ht4qg
# 3843  ibm_sherbrooke  cqtwj4r9nfw0008ht4q0
# 3842  ibm_sherbrooke  cqtwj1036d60008j03d0
# 3841  ibm_sherbrooke  cqtwhxf4x0mg008actm0
# 3840  ibm_sherbrooke  cqtwhsftxzj0008y0df0
# 3839  ibm_sherbrooke  cqtwhn6pkcdg008e3tc0
# 3838  ibm_sherbrooke  cqtwhh64x0mg008actkg
# 3837  ibm_sherbrooke  cqtwhd5pkcdg008e3tbg
# 3836  ibm_sherbrooke  cqtwh9d36d60008j03c0
# 3835  ibm_sherbrooke  cqtwh5m36d60008j03bg
#
#                                              tags  meas_level  shots  \
# 3854  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3853  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3852  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3851  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3850  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3849  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3848  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3847  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3846  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3845  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3844  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3843  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3842  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3841  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3840  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3839  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3838  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3837  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3836  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
# 3835  [Subset 50, 100 rounds, 0 log, xbasis=True]         1.0  800.0
#
#       num_qubits      job_status                    execution_date  \
# 3854         NaN  JobStatus.DONE  2024-03-16 18:43:49.966637+01:00
# 3853         NaN  JobStatus.DONE  2024-03-16 18:43:18.790580+01:00
# 3852         NaN  JobStatus.DONE  2024-03-16 18:42:47.979316+01:00
# 3851         NaN  JobStatus.DONE  2024-03-16 18:42:17.166250+01:00
# 3850         NaN  JobStatus.DONE  2024-03-16 18:41:46.510432+01:00
# 3849         NaN  JobStatus.DONE  2024-03-16 18:41:15.740055+01:00
# 3848         NaN  JobStatus.DONE  2024-03-16 18:40:44.254207+01:00
# 3847         NaN  JobStatus.DONE  2024-03-16 18:40:13.272507+01:00
# 3846         NaN  JobStatus.DONE  2024-03-16 18:39:41.925614+01:00
# 3845         NaN  JobStatus.DONE  2024-03-16 18:39:11.295478+01:00
# 3844         NaN  JobStatus.DONE  2024-03-16 18:38:40.510187+01:00
# 3843         NaN  JobStatus.DONE  2024-03-16 18:38:10.119131+01:00
# 3842         NaN  JobStatus.DONE  2024-03-16 18:37:39.134624+01:00
# 3841         NaN  JobStatus.DONE  2024-03-16 18:37:08.275280+01:00
# 3840         NaN  JobStatus.DONE  2024-03-16 18:36:36.919989+01:00
# 3839         NaN  JobStatus.DONE  2024-03-16 18:36:06.166739+01:00
# 3838         NaN  JobStatus.DONE  2024-03-16 18:35:35.218017+01:00
# 3837         NaN  JobStatus.DONE  2024-03-16 18:35:04.557326+01:00
# 3836         NaN  JobStatus.DONE  2024-03-16 18:34:33.314143+01:00
# 3835         NaN  JobStatus.DONE  2024-03-16 18:34:02.704595+01:00
#
#                        code  distance  rounds logical            descr resets  \
# 3854  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3853  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3852  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3851  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3850  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3849  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3848  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3847  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3846  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3845  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3844  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3843  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3842  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3841  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3840  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3839  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3838  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3837  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3836  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
# 3835  RepetitionCodeCircuit        50     100       0  subset RepCodes    NaN
#
#      xbasis                                          path_info
# 3854   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3853   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3852   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3851   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3850   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3849   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3848   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3847   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3846   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3845   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3844   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3843   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3842   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3841   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3840   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3839   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3838   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3837   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3836   True  {'mean_gate_error': 0.008060744241925, 'min_ga...
# 3835   True  {'mean_gate_error': 0.008060744241925, 'min_ga...

# %% [markdown]
# # Group job ids by closest calibration date

# %%
from datetime import datetime
from Scratch import find_closest_calib_jobs
import pandas as pd

jobs_by_calibration_date = {}
for index, row in md.iterrows():
    job_id = row['job_id']

    _, _, calib_creation_date = find_closest_calib_jobs(tobecalib_job=job_id, verbose=False)

    if calib_creation_date not in jobs_by_calibration_date.keys():
        jobs_by_calibration_date[calib_creation_date] = [job_id]
    else:
        jobs_by_calibration_date[calib_creation_date].append(job_id)

# Takes 15s

# %%
print(jobs_by_calibration_date)
print()
print(f"num of calibrations: {len(jobs_by_calibration_date)}")
print(f"num of jobs per calibration: {([len(jobs) for jobs in jobs_by_calibration_date.values()])}")
# Out:
# {datetime.datetime(2024, 3, 16, 16, 33, 45, 717000, tzinfo=datetime.timezone.utc): ['cqtwkpy88ev000813d9g', 'cqtwkk64x0mg008acts0', 'cqtwkfd4x0mg008actrg', 'cqtwk4m88ev000813d90', 'cqtwk0m88ev000813d8g', 'cqtwjwv4x0mg008actng', 'cqtwjrv9nfw0008ht4rg', 'cqtwjmt36d60008j03dg', 'cqtwjgt9nfw0008ht4r0', 'cqtwjcs4x0mg008actmg', 'cqtwj8s9nfw0008ht4qg'], datetime.datetime(2024, 3, 16, 16, 27, 58, 150000, tzinfo=datetime.timezone.utc): ['cqtwj4r9nfw0008ht4q0', 'cqtwj1036d60008j03d0', 'cqtwhxf4x0mg008actm0', 'cqtwhsftxzj0008y0df0', 'cqtwhn6pkcdg008e3tc0', 'cqtwhh64x0mg008actkg', 'cqtwhd5pkcdg008e3tbg', 'cqtwh9d36d60008j03c0', 'cqtwh5m36d60008j03bg']}
#
# num of calibrations: 2
# num of jobs per calibration: [11, 9]

# %% [markdown]
# # Decode data

# %%
import json

import pymatching
import stim

from soft_info import get_noise_dict_from_backend, get_avgs_from_dict, get_repcode_IQ_map
from soft_info import RepetitionCodeStimCircuit
from soft_info import get_cols_to_keep, generate_subsets_with_center, get_subsample_layout
from Scratch import load_calibration_memory
from src import cpp_soft_info

# SUBSAMPLING
D_NEW = 7


file_name = "./results/MIN_SubS_decoding_test.json"
_DETAILED = False

rel_error = 1
_RESETS = False
nb_intervals = -1

# KDE BANDWIDTHS
lin = [0.4, 0.7, 20]
num_points = 51
bandwidths = np.linspace(lin[0], lin[1], lin[2])


for calib_date in jobs_by_calibration_date.keys():
    # get the noise dict of that date
    noise_dict = get_noise_dict_from_backend(provider, DEVICE, date = calib_date)

    # get the KDE of that date
    nb_shots_calib = None #int(1e4)
    all_memories = load_calibration_memory(provider, tobecalib_backend=DEVICE, other_date=calib_date, nb_shots=nb_shots_calib)
    kde_dict = cpp_soft_info.get_KDEs(all_memories, bandwidths, relError=rel_error, absError=-1, num_points=51) # Less num_points bcs just 1 bandwidth

    for job_id in tqdm(jobs_by_calibration_date[calib_date], desc=f"Decoding jobs of {calib_date} calibration"):
        d = md[md["job_id"] == job_id]["distance"].values[0] 
        T = md[md["job_id"] == job_id]["rounds"].values[0] # Should be 10

        # Get the job
        job = provider.retrieve_job(job_id)
        memory = job.result().get_memory()

        # Get the layout 
        layout_des = job.deserialize_layout(job.initial_layouts()[0]) # only 1 layout
        link_qubits = list(layout_des['link_qubit'].values())
        code_qubits = list(layout_des['code_qubit'].values())
        
        # SUBSAMPLING
        subsets = generate_subsets_with_center(d, D_NEW)

        num_errors_kde = []
        num_errors_hard = []
        for subset in subsets: 
            print(f"subset nb {subsets.index(subset)} out of {len(subsets)}")
            
            cols_to_keep = get_cols_to_keep(subset, T, d)
            IQ_data = memory[:, cols_to_keep]

            # Get the layout
            layout = get_subsample_layout(subset, link_qubits, code_qubits)
            qubit_mapping = get_repcode_IQ_map(layout, synd_rounds=T)

            # Get the noise avgs
            avgs = get_avgs_from_dict(noise_dict, layout)
            noise_list = [avgs["two_gate"], avgs["single_gate"], avgs["t1_err"], avgs["t2_err"]]
            readout = avgs["readout"]
            soft_multiplicator = 0.75
            noise_list += [readout, readout*(1-soft_multiplicator), readout*soft_multiplicator]    
            #[twog_err, sglg_err, t1_err, t2_err, readout_err, hard_err, soft_err]

            # Stim model
            subsampling = (D_NEW != d)
            code = RepetitionCodeStimCircuit(D_NEW, T, xbasis=XBASIS, resets=_RESETS, 
                                            noise_list=noise_list, subsampling=subsampling)
            model = code.circuits[LOGICAL].detector_error_model(decompose_errors=False)
            _NTNN_EDGES = False

            ### DECODING ###
            # result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS, 
            #                                 qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
            #                                 nb_intervals=nb_intervals)
            # num_errors_kde.append(result_kde.num_errors)

            # result_hard = cpp_soft_info.decode_hard_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
            #                                             qubit_mapping, kde_dict, _DETAILED,
            #                                             relError=rel_error, absError=-1, _ntnn_edges = _NTNN_EDGES)
            # num_errors_hard.append(result_hard.num_errors)

            result_soft, result_hard = cpp_soft_info.decode_all_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
                                                                    qubit_mapping, kde_dict, relError=rel_error, 
                                                                    absError=-1, nb_intervals=nb_intervals)
            
            num_errors_kde.append(result_soft.num_errors)
            num_errors_hard.append(result_hard.num_errors)
        

        print("num_errors_kde", num_errors_kde)
        print("num_errors_hard", num_errors_hard)
        print("mean num_errors_kde", np.mean(num_errors_kde))
        print("mean num_errors_hard", np.mean(num_errors_hard))

        result_kde_json = {
            "decoding": "kde",
            "num_errors": np.mean(num_errors_kde),
            "error_list": num_errors_kde,
            "additional_info": {
                "rel_error": rel_error,
                "bandwidth_linspace": lin,
                "num_points_bandwidths": num_points,
            },
        }

        result_hard_json = {
            "decoding": "hard",
            "num_errors": np.mean(num_errors_hard),
            "error_list": num_errors_hard,
            "noise_list": noise_list,
        }

        with open(file_name, "r") as f:
            data = json.load(f)
            if job_id not in data.keys():
                data[job_id] = [state, result_kde_json, result_hard_json]
            else:
                data[job_id].append(result_kde_json)
                data[job_id].append(result_hard_json)
        
        with open(file_name, "w") as f:
            json.dump(data, f, indent=4)
# Out:
# 18:34:41 Warning: Z0 decoding. Negative T2 error -0.08 % for qubit 46, setting to 0.. IN FILE: /Users/mha/My_Drive/Desktop/Studium/Physik/MSc/Semester_3/IBM/IBM_GIT/Soft-Info/src/soft_info/Hardware/backend_noise.py, LINE: 52
# 18:34:41 Warning: Z0 decoding. Negative T2 error -2.03 % for qubit 55, setting to 0.. IN FILE: /Users/mha/My_Drive/Desktop/Studium/Physik/MSc/Semester_3/IBM/IBM_GIT/Soft-Info/src/soft_info/Hardware/backend_noise.py, LINE: 52
# 18:34:41 Warning: Z0 decoding. Negative T2 error -0.21 % for qubit 90, setting to 0.. IN FILE: /Users/mha/My_Drive/Desktop/Studium/Physik/MSc/Semester_3/IBM/IBM_GIT/Soft-Info/src/soft_info/Hardware/backend_noise.py, LINE: 52
# Found jobs for backend ibm_sherbrooke with closest execution date 2024-03-16 16:48:40.204724+00:00.
# Decoding jobs of 2024-03-16 16:33:45.717000+00:00 calibration:   0%|          | 0/11 [00:00<?, ?it/s]
# subset nb 0 out of 9
# subset nb 1 out of 9
# subset nb 2 out of 9
# subset nb 3 out of 9
# subset nb 4 out of 9
# subset nb 5 out of 9
# subset nb 6 out of 9
# subset nb 7 out of 9
# subset nb 8 out of 9
# Decoding jobs of 2024-03-16 16:33:45.717000+00:00 calibration:   9%|▉         | 1/11 [01:01<10:19, 61.96s/it]
# num_errors_kde [313, 153, 220, 9, 230, 201, 272, 308, 133]
# num_errors_hard [335, 224, 234, 10, 231, 207, 272, 311, 128]
# mean num_errors_kde 204.33333333333334
# mean num_errors_hard 216.88888888888889
# subset nb 0 out of 9
# subset nb 1 out of 9
# subset nb 2 out of 9
# subset nb 3 out of 9
# subset nb 4 out of 9
# subset nb 5 out of 9
# subset nb 6 out of 9
# subset nb 7 out of 9
# subset nb 8 out of 9
# Decoding jobs of 2024-03-16 16:33:45.717000+00:00 calibration:  18%|█▊        | 2/11 [02:05<09:25, 62.82s/it]
# num_errors_kde [275, 156, 250, 10, 189, 215, 271, 286, 167]
# num_errors_hard [305, 248, 274, 18, 205, 217, 303, 309, 145]
# mean num_errors_kde 202.11111111111111
# mean num_errors_hard 224.88888888888889
# subset nb 0 out of 9
# subset nb 1 out of 9
# subset nb 2 out of 9
# subset nb 3 out of 9
# subset nb 4 out of 9
# subset nb 5 out of 9
# subset nb 6 out of 9
# subset nb 7 out of 9
# subset nb 8 out of 9
# Decoding jobs of 2024-03-16 16:33:45.717000+00:00 calibration:  27%|██▋       | 3/11 [03:11<08:35, 64.38s/it]
# num_errors_kde [266, 166, 253, 13, 175, 209, 254, 308, 118]
# num_errors_hard [306, 244, 248, 12, 216, 209, 292, 297, 129]
# mean num_errors_kde 195.77777777777777
# mean num_errors_hard 217.0
# subset nb 0 out of 9
# subset nb 1 out of 9
# subset nb 2 out of 9
# subset nb 3 out of 9
# subset nb 4 out of 9
# subset nb 5 out of 9
# subset nb 6 out of 9
# subset nb 7 out of 9
# subset nb 8 out of 9
# Decoding jobs of 2024-03-16 16:33:45.717000+00:00 calibration:  36%|███▋      | 4/11 [04:15<07:29, 64.20s/it]
# num_errors_kde [289, 166, 238, 19, 207, 223, 310, 285, 146]
# num_errors_hard [312, 242, 250, 30, 238, 200, 320, 312, 126]
# mean num_errors_kde 209.22222222222223
# mean num_errors_hard 225.55555555555554
# subset nb 0 out of 9
# subset nb 1 out of 9
# subset nb 2 out of 9
# Decoding jobs of 2024-03-16 16:33:45.717000+00:00 calibration:  36%|███▋      | 4/11 [04:39<08:08, 69.84s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 92
#      79 _NTNN_EDGES = False
#      81 ### DECODING ###
#      82 # result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
#      83 #                                 qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
#    (...)
#      89 #                                             relError=rel_error, absError=-1, _ntnn_edges = _NTNN_EDGES)
#      90 # num_errors_hard.append(result_hard.num_errors)
# ---> 92 result_soft, result_hard = cpp_soft_info.decode_all_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
#      93                                                         qubit_mapping, kde_dict, relError=rel_error,
#      94                                                         absError=-1, nb_intervals=nb_intervals)
#      96 num_errors_kde.append(result_soft.num_errors)
#      97 num_errors_hard.append(result_hard.num_errors)
#
# KeyboardInterrupt:
