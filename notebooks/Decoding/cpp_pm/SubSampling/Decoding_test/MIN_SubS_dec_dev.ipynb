# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
from result_saver import SaverProvider
provider = SaverProvider()

# %%
from Scratch import metadata_loader
import numpy as np
from tqdm import tqdm

DEVICE = "ibm_sherbrooke"
LOGICAL = str(0)
XBASIS = True
ROUNDS = 10

state = "X" if XBASIS else "Z"
state += LOGICAL
print(f"state = {state}")


# Load the metadata
md = metadata_loader(True, True)
md = md[md["job_status"] == "JobStatus.DONE"]
md = md[md["code"] == "RepetitionCodeCircuit"]
md = md[md["descr"] == 'subset RepCodes']
md = md.dropna(subset=["rounds"])
md = md[md["meas_level"] == 1]
md['rounds'] = md['rounds'].astype(int)
md['distance'] = md['distance'].astype(int)

md = md[md["backend_name"] == DEVICE]
md = md[md["logical"] == LOGICAL]
md = md[md["xbasis"] == XBASIS]
md = md[md["rounds"] == ROUNDS]

md = md[16:]
print("shape:", md.shape)
md
# Out:
# state = X0
# shape: (20, 18)
#                          creation_date             notebook_name  \
# 2747  2024-03-15 12:43:20.091000+01:00  Sherbrooke_RepCodes_jobs
# 2746  2024-03-15 12:43:17.513000+01:00  Sherbrooke_RepCodes_jobs
# 2745  2024-03-15 12:43:15.014000+01:00  Sherbrooke_RepCodes_jobs
# 2744  2024-03-15 12:43:12.562000+01:00  Sherbrooke_RepCodes_jobs
# 2743  2024-03-15 12:43:10.100000+01:00  Sherbrooke_RepCodes_jobs
# 2742  2024-03-15 12:43:07.735000+01:00  Sherbrooke_RepCodes_jobs
# 2741  2024-03-15 12:43:05.175000+01:00  Sherbrooke_RepCodes_jobs
# 2740  2024-03-15 12:43:02.057000+01:00  Sherbrooke_RepCodes_jobs
# 2739  2024-03-15 12:42:59.639000+01:00  Sherbrooke_RepCodes_jobs
# 2738  2024-03-15 12:42:57.194000+01:00  Sherbrooke_RepCodes_jobs
# 2737  2024-03-15 12:42:54.633000+01:00  Sherbrooke_RepCodes_jobs
# 2736  2024-03-15 12:42:52.136000+01:00  Sherbrooke_RepCodes_jobs
# 2735  2024-03-15 12:42:49.639000+01:00  Sherbrooke_RepCodes_jobs
# 2734  2024-03-15 12:42:47.172000+01:00  Sherbrooke_RepCodes_jobs
# 2733  2024-03-15 12:42:44.564000+01:00  Sherbrooke_RepCodes_jobs
# 2732  2024-03-15 12:42:41.304000+01:00  Sherbrooke_RepCodes_jobs
# 2731  2024-03-15 12:42:38.308000+01:00  Sherbrooke_RepCodes_jobs
# 2730  2024-03-15 12:42:35.723000+01:00  Sherbrooke_RepCodes_jobs
# 2729  2024-03-15 12:42:33.229000+01:00  Sherbrooke_RepCodes_jobs
# 2728  2024-03-15 12:42:30.315000+01:00  Sherbrooke_RepCodes_jobs
#
#         backend_name                job_id  \
# 2747  ibm_sherbrooke  cqt38nt9nfw0008hrgg0
# 2746  ibm_sherbrooke  cqt38na9nfw0008hrgfg
# 2745  ibm_sherbrooke  cqt38mj4x0mg008agq00
# 2744  ibm_sherbrooke  cqt38m29nfw0008hrgf0
# 2743  ibm_sherbrooke  cqt38ka36d60008hyezg
# 2742  ibm_sherbrooke  cqt38jt4x0mg008agpzg
# 2741  ibm_sherbrooke  cqt38ja4x0mg008agpz0
# 2740  ibm_sherbrooke  cqt38hatxzj0008xymh0
# 2739  ibm_sherbrooke  cqt38gtch2mg008qv0j0
# 2738  ibm_sherbrooke  cqt38ga9nfw0008hrgeg
# 2737  ibm_sherbrooke  cqt38fh36d60008hyez0
# 2736  ibm_sherbrooke  cqt38estxzj0008xymgg
# 2735  ibm_sherbrooke  cqt38e9txzj0008xymg0
# 2734  ibm_sherbrooke  cqt38dsch2mg008qv0hg
# 2733  ibm_sherbrooke  cqt38d14x0mg008agpyg
# 2732  ibm_sherbrooke  cqt38c94x0mg008agpy0
# 2731  ibm_sherbrooke  cqt38bh9nfw0008hrge0
# 2730  ibm_sherbrooke  cqt38as4x0mg008agpxg
# 2729  ibm_sherbrooke  cqt38a9ch2mg008qv0h0
# 2728  ibm_sherbrooke  cqt389h88ev000811j0g
#
#                                             tags  meas_level   shots  \
# 2747  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2746  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2745  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2744  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2743  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2742  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2741  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2740  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2739  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2738  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2737  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2736  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2735  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2734  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2733  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2732  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2731  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2730  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2729  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
# 2728  [Subset 52, 10 rounds, 0 log, xbasis=True]         1.0  6525.0
#
#       num_qubits      job_status                    execution_date  \
# 2747         NaN  JobStatus.DONE  2024-03-15 16:48:51.190683+01:00
# 2746         NaN  JobStatus.DONE  2024-03-15 16:48:23.434564+01:00
# 2745         NaN  JobStatus.DONE  2024-03-15 16:47:55.682870+01:00
# 2744         NaN  JobStatus.DONE  2024-03-15 16:47:28.089485+01:00
# 2743         NaN  JobStatus.DONE  2024-03-15 16:47:00.403039+01:00
# 2742         NaN  JobStatus.DONE  2024-03-15 16:46:32.755635+01:00
# 2741         NaN  JobStatus.DONE  2024-03-15 16:46:05.140994+01:00
# 2740         NaN  JobStatus.DONE  2024-03-15 16:45:37.385341+01:00
# 2739         NaN  JobStatus.DONE  2024-03-15 16:45:09.251371+01:00
# 2738         NaN  JobStatus.DONE  2024-03-15 16:44:41.740733+01:00
# 2737         NaN  JobStatus.DONE  2024-03-15 16:44:13.879097+01:00
# 2736         NaN  JobStatus.DONE  2024-03-15 16:43:46.218925+01:00
# 2735         NaN  JobStatus.DONE  2024-03-15 16:41:03.208640+01:00
# 2734         NaN  JobStatus.DONE  2024-03-15 16:40:34.869607+01:00
# 2733         NaN  JobStatus.DONE  2024-03-15 16:40:06.510579+01:00
# 2732         NaN  JobStatus.DONE  2024-03-15 16:39:38.032598+01:00
# 2731         NaN  JobStatus.DONE  2024-03-15 16:39:10.329436+01:00
# 2730         NaN  JobStatus.DONE  2024-03-15 16:38:42.243885+01:00
# 2729         NaN  JobStatus.DONE  2024-03-15 16:38:14.048477+01:00
# 2728         NaN  JobStatus.DONE  2024-03-15 16:37:45.758738+01:00
#
#                        code  distance  rounds logical            descr resets  \
# 2747  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2746  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2745  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2744  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2743  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2742  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2741  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2740  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2739  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2738  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2737  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2736  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2735  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2734  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2733  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2732  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2731  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2730  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2729  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2728  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
#
#      xbasis                                          path_info
# 2747   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2746   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2745   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2744   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2743   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2742   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2741   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2740   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2739   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2738   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2737   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2736   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2735   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2734   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2733   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2732   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2731   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2730   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2729   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2728   True  {'mean_gate_error': 0.007963147793478, 'min_ga...

# %% [markdown]
# # Group job ids by closest calibration date

# %%
from datetime import datetime
from Scratch import find_closest_calib_jobs
import pandas as pd

jobs_by_calibration_date = {}
for index, row in md.iterrows():
    job_id = row['job_id']

    _, _, calib_creation_date = find_closest_calib_jobs(tobecalib_job=job_id, verbose=False)

    if calib_creation_date not in jobs_by_calibration_date.keys():
        jobs_by_calibration_date[calib_creation_date] = [job_id]
    else:
        jobs_by_calibration_date[calib_creation_date].append(job_id)

# Takes 15s

# %%
print(jobs_by_calibration_date)
print()
print(f"num of calibrations: {len(jobs_by_calibration_date)}")
print(f"num of jobs per calibration: {([len(jobs) for jobs in jobs_by_calibration_date.values()])}")
# Out:
# {datetime.datetime(2024, 3, 15, 11, 43, 22, 813000, tzinfo=datetime.timezone.utc): ['cqt38nt9nfw0008hrgg0', 'cqt38na9nfw0008hrgfg', 'cqt38mj4x0mg008agq00', 'cqt38m29nfw0008hrgf0', 'cqt38ka36d60008hyezg', 'cqt38jt4x0mg008agpzg', 'cqt38ja4x0mg008agpz0', 'cqt38hatxzj0008xymh0', 'cqt38gtch2mg008qv0j0', 'cqt38ga9nfw0008hrgeg', 'cqt38fh36d60008hyez0', 'cqt38estxzj0008xymgg'], datetime.datetime(2024, 3, 15, 11, 42, 23, 886000, tzinfo=datetime.timezone.utc): ['cqt38e9txzj0008xymg0', 'cqt38dsch2mg008qv0hg', 'cqt38d14x0mg008agpyg', 'cqt38c94x0mg008agpy0', 'cqt38bh9nfw0008hrge0', 'cqt38as4x0mg008agpxg', 'cqt38a9ch2mg008qv0h0', 'cqt389h88ev000811j0g']}
#
# num of calibrations: 2
# num of jobs per calibration: [12, 8]

# %% [markdown]
# # Decode data

# %%
import json

import pymatching
import stim

from soft_info import get_noise_dict_from_backend, get_avgs_from_dict, get_repcode_IQ_map
from soft_info import RepetitionCodeStimCircuit
from soft_info import get_cols_to_keep, generate_subsets_with_center, get_subsample_layout
from Scratch import load_calibration_memory
import cpp_soft_info

# SUBSAMPLING
D_NEW = 11


file_name = "./results/MIN_SubS_decoding_test.json"
_DETAILED = False

rel_error = 1
_RESETS = False
nb_intervals = -1

# KDE BANDWIDTHS
lin = [0.4, 0.7, 20]
num_points = 51
bandwidths = np.linspace(lin[0], lin[1], lin[2])


for calib_date in jobs_by_calibration_date.keys():
    # get the noise dict of that date
    noise_dict = get_noise_dict_from_backend(provider, DEVICE, date = calib_date)

    # get the KDE of that date
    nb_shots_calib = int(1e4)
    all_memories = load_calibration_memory(provider, tobecalib_backend=DEVICE, other_date=calib_date, nb_shots=nb_shots_calib)
    kde_dict = cpp_soft_info.get_KDEs(all_memories, bandwidths, relError=rel_error, absError=-1, num_points=51) # Less num_points bcs just 1 bandwidth

    for job_id in tqdm(jobs_by_calibration_date[calib_date], desc=f"Decoding jobs of {calib_date} calibration"):
        d = md[md["job_id"] == job_id]["distance"].values[0] 
        T = md[md["job_id"] == job_id]["rounds"].values[0] # Should be 10

        # Get the job
        job = provider.retrieve_job(job_id)
        memory = job.result().get_memory()

        # Get the layout 
        layout_des = job.deserialize_layout(job.initial_layouts()[0]) # only 1 layout
        link_qubits = list(layout_des['link_qubit'].values())
        code_qubits = list(layout_des['code_qubit'].values())
        
        # SUBSAMPLING
        subsets = generate_subsets_with_center(d, D_NEW)

        num_errors_kde = []
        num_errors_hard = []
        for subset in subsets: 
            print(f"subset nb {subsets.index(subset)} out of {len(subsets)}")
            
            cols_to_keep = get_cols_to_keep(subset, T, d)
            IQ_data = memory[:, cols_to_keep]

            # Get the layout
            layout = get_subsample_layout(subset, link_qubits, code_qubits)
            qubit_mapping = get_repcode_IQ_map(layout, synd_rounds=T)

            # Get the noise avgs
            avgs = get_avgs_from_dict(noise_dict, layout)
            noise_list = [avgs["two_gate"], avgs["single_gate"], avgs["t1_err"], avgs["t2_err"]]
            readout = avgs["readout"]
            soft_multiplicator = 0.75
            noise_list += [readout, readout*(1-soft_multiplicator), readout*soft_multiplicator]    
            #[twog_err, sglg_err, t1_err, t2_err, readout_err, hard_err, soft_err]

            # Stim model
            subsampling = (D_NEW != d)
            code = RepetitionCodeStimCircuit(D_NEW, T, xbasis=XBASIS, resets=_RESETS, 
                                            noise_list=noise_list, subsampling=subsampling)
            model = code.circuits[LOGICAL].detector_error_model(decompose_errors=False)
            _NTNN_EDGES = False

            ### DECODING ###
            result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS, 
                                            qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
                                            nb_intervals=nb_intervals)
            num_errors_kde.append(result_kde.num_errors)

            result_hard = cpp_soft_info.decode_hard_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
                                                        qubit_mapping, kde_dict, _DETAILED,
                                                        relError=rel_error, absError=-1, _ntnn_edges = _NTNN_EDGES)
            num_errors_hard.append(result_hard.num_errors)
        

        print("num_errors_kde", num_errors_kde)
        print("num_errors_hard", num_errors_hard)
        print("mean num_errors_kde", np.mean(num_errors_kde))
        print("mean num_errors_hard", np.mean(num_errors_hard))

        result_kde_json = {
            "decoding": "kde",
            "num_errors": np.mean(num_errors_kde),
            "error_list": num_errors_kde,
            "additional_info": {
                "rel_error": rel_error,
                "bandwidth_linspace": lin,
                "num_points_bandwidths": num_points,
            },
        }

        result_hard_json = {
            "decoding": "hard",
            "num_errors": np.mean(num_errors_hard),
            "error_list": num_errors_hard,
            "noise_list": noise_list,
        }

        with open(file_name, "r") as f:
            data = json.load(f)
            if job_id not in data.keys():
                data[job_id] = [state, result_kde_json, result_hard_json]
            else:
                data[job_id].append(result_kde_json)
                data[job_id].append(result_hard_json)
        
        with open(file_name, "w") as f:
            json.dump(data, f, indent=4)
# Out:
# 16:41:21 Warning: Negative T2 error -0.03 % for qubit 115, setting to 0.. IN FILE: /Users/mha/My_Drive/Desktop/Studium/Physik/MSc/Semester_3/IBM/IBM_GIT/Soft-Info/src/soft_info/Hardware/backend_noise.py, LINE: 52
# Found jobs for backend ibm_sherbrooke with closest execution date 2024-03-15 15:04:39.994509+00:00.
# Decoding jobs of 2024-03-15 11:43:22.813000+00:00 calibration:   0%|          | 0/12 [00:00<?, ?it/s]
# subset nb 0 out of 6
# subset nb 1 out of 6
# subset nb 2 out of 6
# subset nb 3 out of 6
# subset nb 4 out of 6
# subset nb 5 out of 6
# Decoding jobs of 2024-03-15 11:43:22.813000+00:00 calibration:   8%|▊         | 1/12 [01:20<14:50, 80.96s/it]
# num_errors_kde [50, 65, 5, 9, 18, 8]
# num_errors_hard [60, 82, 5, 11, 22, 5]
# mean num_errors_kde 25.833333333333332
# mean num_errors_hard 30.833333333333332
# subset nb 0 out of 6
# subset nb 1 out of 6
# subset nb 2 out of 6
# subset nb 3 out of 6
# subset nb 4 out of 6
# subset nb 5 out of 6
# Decoding jobs of 2024-03-15 11:43:22.813000+00:00 calibration:  17%|█▋        | 2/12 [02:45<13:48, 82.88s/it]
# num_errors_kde [58, 81, 2, 6, 13, 2]
# num_errors_hard [92, 99, 2, 5, 17, 5]
# mean num_errors_kde 27.0
# mean num_errors_hard 36.666666666666664
# subset nb 0 out of 6
# subset nb 1 out of 6
# subset nb 2 out of 6
# subset nb 3 out of 6
# subset nb 4 out of 6
# subset nb 5 out of 6
# Decoding jobs of 2024-03-15 11:43:22.813000+00:00 calibration:  25%|██▌       | 3/12 [04:05<12:16, 81.88s/it]
# num_errors_kde [45, 96, 2, 5, 22, 8]
# num_errors_hard [64, 140, 3, 7, 22, 5]
# mean num_errors_kde 29.666666666666668
# mean num_errors_hard 40.166666666666664
# subset nb 0 out of 6
# subset nb 1 out of 6
# subset nb 2 out of 6
# subset nb 3 out of 6
# subset nb 4 out of 6
# subset nb 5 out of 6
# Decoding jobs of 2024-03-15 11:43:22.813000+00:00 calibration:  33%|███▎      | 4/12 [05:25<10:47, 80.98s/it]
# num_errors_kde [55, 80, 0, 5, 34, 14]
# num_errors_hard [69, 105, 1, 7, 36, 7]
# mean num_errors_kde 31.333333333333332
# mean num_errors_hard 37.5
# subset nb 0 out of 6
# subset nb 1 out of 6
# subset nb 2 out of 6
# subset nb 3 out of 6
# Decoding jobs of 2024-03-15 11:43:22.813000+00:00 calibration:  33%|███▎      | 4/12 [06:13<12:27, 93.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 82
#      79 _NTNN_EDGES = False
#      81 ### DECODING ###
# ---> 82 result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
#      83                                 qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
#      84                                 nb_intervals=nb_intervals)
#      85 num_errors_kde.append(result_kde.num_errors)
#      87 result_hard = cpp_soft_info.decode_hard_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
#      88                                             qubit_mapping, kde_dict, _DETAILED,
#      89                                             relError=rel_error, absError=-1, _ntnn_edges = _NTNN_EDGES)
#
# KeyboardInterrupt:
