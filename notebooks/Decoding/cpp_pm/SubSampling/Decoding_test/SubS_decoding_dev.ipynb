# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
from result_saver import SaverProvider
provider = SaverProvider()

# %%
from Scratch import metadata_loader
import numpy as np
from tqdm import tqdm

DEVICE = "ibm_sherbrooke"
LOGICAL = str(0)
XBASIS = False
ROUNDS = 10


# Load the metadata
md = metadata_loader(True, True)
md = md[md["job_status"] == "JobStatus.DONE"]
md = md[md["code"] == "RepetitionCodeCircuit"]
md = md[md["descr"] == 'subset RepCodes']
md = md.dropna(subset=["rounds"])
md = md[md["meas_level"] == 1]
md['rounds'] = md['rounds'].astype(int)
md['distance'] = md['distance'].astype(int)

md = md[md["backend_name"] == DEVICE]
md = md[md["logical"] == LOGICAL]
md = md[md["xbasis"] == XBASIS]
md = md[md["rounds"] == ROUNDS]

print(md.shape)
md
# Out:
# (20, 18)
#                          creation_date             notebook_name  \
# 2691  2024-03-15 12:36:49.772000+01:00  Sherbrooke_RepCodes_jobs
# 2690  2024-03-15 12:36:44.891000+01:00  Sherbrooke_RepCodes_jobs
# 2689  2024-03-15 12:36:41.100000+01:00  Sherbrooke_RepCodes_jobs
# 2688  2024-03-15 12:36:37.683000+01:00  Sherbrooke_RepCodes_jobs
# 2687  2024-03-15 12:36:34.829000+01:00  Sherbrooke_RepCodes_jobs
# 2686  2024-03-15 12:36:32.131000+01:00  Sherbrooke_RepCodes_jobs
# 2685  2024-03-15 12:36:29.331000+01:00  Sherbrooke_RepCodes_jobs
# 2684  2024-03-15 12:36:22.764000+01:00  Sherbrooke_RepCodes_jobs
# 2683  2024-03-15 12:36:19.161000+01:00  Sherbrooke_RepCodes_jobs
# 2682  2024-03-15 12:36:16.772000+01:00  Sherbrooke_RepCodes_jobs
# 2681  2024-03-15 12:36:13.109000+01:00  Sherbrooke_RepCodes_jobs
# 2680  2024-03-15 12:36:08.420000+01:00  Sherbrooke_RepCodes_jobs
# 2679  2024-03-15 12:36:05.596000+01:00  Sherbrooke_RepCodes_jobs
# 2678  2024-03-15 12:36:01.394000+01:00  Sherbrooke_RepCodes_jobs
# 2677  2024-03-15 12:35:58.927000+01:00  Sherbrooke_RepCodes_jobs
# 2676  2024-03-15 12:35:56.197000+01:00  Sherbrooke_RepCodes_jobs
# 2675  2024-03-15 12:35:53.113000+01:00  Sherbrooke_RepCodes_jobs
# 2674  2024-03-15 12:35:50.185000+01:00  Sherbrooke_RepCodes_jobs
# 2673  2024-03-15 12:35:47.624000+01:00  Sherbrooke_RepCodes_jobs
# 2672  2024-03-15 12:35:45.147000+01:00  Sherbrooke_RepCodes_jobs
#
#         backend_name                job_id  \
# 2691  ibm_sherbrooke  cqt35me9nfw0008hrg8g
# 2690  ibm_sherbrooke  cqt35k6txzj0008xymcg
# 2689  ibm_sherbrooke  cqt35j636d60008hyesg
# 2688  ibm_sherbrooke  cqt35he36d60008hyes0
# 2687  ibm_sherbrooke  cqt35gpch2mg008qv0c0
# 2686  ibm_sherbrooke  cqt35fxtxzj0008xymc0
# 2685  ibm_sherbrooke  cqt35fd9nfw0008hrg80
# 2684  ibm_sherbrooke  cqt35dn88ev000811hyg
# 2683  ibm_sherbrooke  cqt35cx36d60008hyerg
# 2682  ibm_sherbrooke  cqt35c59nfw0008hrg7g
# 2681  ibm_sherbrooke  cqt35b59nfw0008hrg70
# 2680  ibm_sherbrooke  cqt35a59nfw0008hrg6g
# 2679  ibm_sherbrooke  cqt359d36d60008hyer0
# 2678  ibm_sherbrooke  cqt358d36d60008hyeqg
# 2677  ibm_sherbrooke  cqt357m9nfw0008hrg60
# 2676  ibm_sherbrooke  cqt35749nfw0008hrg5g
# 2675  ibm_sherbrooke  cqt356436d60008hyeq0
# 2674  ibm_sherbrooke  cqt355mtxzj0008xymbg
# 2673  ibm_sherbrooke  cqt354wch2mg008qv0bg
# 2672  ibm_sherbrooke  cqt354cch2mg008qv0b0
#
#                                              tags  meas_level   shots  \
# 2691  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2690  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2689  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2688  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2687  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2686  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2685  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2684  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2683  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2682  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2681  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2680  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2679  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2678  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2677  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2676  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2675  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2674  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2673  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
# 2672  [Subset 52, 10 rounds, 0 log, xbasis=False]         1.0  6525.0
#
#       num_qubits      job_status                    execution_date  \
# 2691         NaN  JobStatus.DONE  2024-03-15 16:18:18.801755+01:00
# 2690         NaN  JobStatus.DONE  2024-03-15 16:17:51.270492+01:00
# 2689         NaN  JobStatus.DONE  2024-03-15 16:17:23.860784+01:00
# 2688         NaN  JobStatus.DONE  2024-03-15 16:16:56.520613+01:00
# 2687         NaN  JobStatus.DONE  2024-03-15 16:16:28.746003+01:00
# 2686         NaN  JobStatus.DONE  2024-03-15 16:16:01.491464+01:00
# 2685         NaN  JobStatus.DONE  2024-03-15 16:15:34.188938+01:00
# 2684         NaN  JobStatus.DONE  2024-03-15 16:15:06.527072+01:00
# 2683         NaN  JobStatus.DONE  2024-03-15 16:14:39.096869+01:00
# 2682         NaN  JobStatus.DONE  2024-03-15 16:14:11.109042+01:00
# 2681         NaN  JobStatus.DONE  2024-03-15 16:13:43.569554+01:00
# 2680         NaN  JobStatus.DONE  2024-03-15 16:13:16.306529+01:00
# 2679         NaN  JobStatus.DONE  2024-03-15 16:11:36.651095+01:00
# 2678         NaN  JobStatus.DONE  2024-03-15 16:11:08.801645+01:00
# 2677         NaN  JobStatus.DONE  2024-03-15 16:10:41.782402+01:00
# 2676         NaN  JobStatus.DONE  2024-03-15 16:10:14.618728+01:00
# 2675         NaN  JobStatus.DONE  2024-03-15 16:09:47.552273+01:00
# 2674         NaN  JobStatus.DONE  2024-03-15 16:09:19.768301+01:00
# 2673         NaN  JobStatus.DONE  2024-03-15 16:08:52.414168+01:00
# 2672         NaN  JobStatus.DONE  2024-03-15 16:08:24.612441+01:00
#
#                        code  distance  rounds logical            descr resets  \
# 2691  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2690  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2689  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2688  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2687  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2686  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2685  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2684  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2683  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2682  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2681  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2680  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2679  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2678  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2677  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2676  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2675  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2674  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2673  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
# 2672  RepetitionCodeCircuit        52      10       0  subset RepCodes    NaN
#
#      xbasis                                          path_info
# 2691  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2690  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2689  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2688  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2687  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2686  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2685  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2684  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2683  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2682  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2681  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2680  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2679  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2678  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2677  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2676  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2675  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2674  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2673  False  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2672  False  {'mean_gate_error': 0.007963147793478, 'min_ga...

# %% [markdown]
# # Group job ids by closest calibration date

# %%
from datetime import datetime
from Scratch import find_closest_calib_jobs
import pandas as pd

jobs_by_calibration_date = {}
for index, row in md.iterrows():
    job_id = row['job_id']

    _, _, calib_creation_date = find_closest_calib_jobs(tobecalib_job=job_id, verbose=False)

    if calib_creation_date not in jobs_by_calibration_date.keys():
        jobs_by_calibration_date[calib_creation_date] = [job_id]
    else:
        jobs_by_calibration_date[calib_creation_date].append(job_id)

# Takes 15s

# %%
print(jobs_by_calibration_date)
print()
print(f"num of calibrations: {len(jobs_by_calibration_date)}")
print(f"num of jobs per calibration: {([len(jobs) for jobs in jobs_by_calibration_date.values()])}")
# Out:
# {datetime.datetime(2024, 3, 15, 11, 36, 53, 764000, tzinfo=datetime.timezone.utc): ['cqt35me9nfw0008hrg8g', 'cqt35k6txzj0008xymcg', 'cqt35j636d60008hyesg', 'cqt35he36d60008hyes0', 'cqt35gpch2mg008qv0c0', 'cqt35fxtxzj0008xymc0', 'cqt35fd9nfw0008hrg80', 'cqt35dn88ev000811hyg', 'cqt35cx36d60008hyerg', 'cqt35c59nfw0008hrg7g', 'cqt35b59nfw0008hrg70', 'cqt35a59nfw0008hrg6g'], datetime.datetime(2024, 3, 15, 11, 35, 35, 729000, tzinfo=datetime.timezone.utc): ['cqt359d36d60008hyer0', 'cqt358d36d60008hyeqg', 'cqt357m9nfw0008hrg60', 'cqt35749nfw0008hrg5g', 'cqt356436d60008hyeq0', 'cqt355mtxzj0008xymbg', 'cqt354wch2mg008qv0bg', 'cqt354cch2mg008qv0b0']}

# %% [markdown]
# # Decode data

# %%
import numpy as np
def get_cols_to_keep_ini(d, d_new, T):  
    """Returns the columns to keep for a subsample RepCode of distance d_new"""      
    cols_to_keep_ini = []
    for i in range(T):
        a_cols_to_keep = range(i*(d-1), i*(d-1)+(d_new-1))
        cols_to_keep_ini.extend(a_cols_to_keep)
    c_cols_to_keep_ini = range(T*(d-1), T*(d-1)+d_new)
    cols_to_keep_ini.extend(c_cols_to_keep_ini)

    return cols_to_keep_ini

# %%
import json

import pymatching
import stim

from soft_info import get_noise_dict_from_backend, get_avgs_from_dict, get_repcode_IQ_map, RepetitionCodeStimCircuit
from Scratch import load_calibration_memory
import cpp_soft_info

# SUBSAMPLING
D_NEW = 25


file_name = "./results/SubS_decoding_test.json"
_DETAILED = False

rel_error = 1
_RESETS = False
nb_intervals = -1

# KDE BANDWIDTHS
lin = [0.4, 0.7, 20]
num_points = 51
bandwidths = np.linspace(lin[0], lin[1], lin[2])


for calib_date in jobs_by_calibration_date.keys():
    # get the noise dict of that date
    noise_dict = get_noise_dict_from_backend(provider, DEVICE, date = calib_date)

    # get the KDE of that date
    all_memories = load_calibration_memory(provider, tobecalib_backend=DEVICE, other_date=calib_date)
    kde_dict = cpp_soft_info.get_KDEs(all_memories, bandwidths, relError=rel_error, absError=-1, num_points=51) # Less num_points bcs just 1 bandwidth

    for job_id in tqdm(jobs_by_calibration_date[calib_date], desc=f"Decoding jobs of {calib_date} calibration"):
        d = md[md["job_id"] == job_id]["distance"].values[0] 
        T = md[md["job_id"] == job_id]["rounds"].values[0] # Should be 10

        # Get the job
        job = provider.retrieve_job(job_id)
        memory = job.result().get_memory()

        # Get the layout 
        layout_des = job.deserialize_layout(job.initial_layouts()[0]) # only 1 layout
        link_qubits = list(layout_des['link_qubit'].values())
        code_qubits = list(layout_des['code_qubit'].values())
        
        # SUBSAMPLING
        cols_to_keep_ini = get_cols_to_keep_ini(d, D_NEW, T)
        nb_of_subsamples = d - D_NEW + 1

        print("start subsampling")
        num_errors_kde = []
        num_errors_hard = []
        for i in tqdm(range(nb_of_subsamples), desc="Samples:"): # +1 to have the original in there as well
            cols_to_keep_new = [x+i for x in cols_to_keep_ini]
            IQ_data = memory[:, cols_to_keep_new]

            # Get the layout
            layout = link_qubits[i:D_NEW-1+i] + code_qubits[i:D_NEW+i]
            qubit_mapping = get_repcode_IQ_map(layout, synd_rounds=T)

            # Get the noise avgs
            avgs = get_avgs_from_dict(noise_dict, layout)
            noise_list = [avgs["two_gate"], avgs["single_gate"], avgs["t1_err"], avgs["t2_err"]]
            readout = avgs["readout"]
            soft_multiplicator = 0
            noise_list += [readout, readout*(1-soft_multiplicator), readout*soft_multiplicator]    
            #[twog_err, sglg_err, t1_err, t2_err, readout_err, hard_err, soft_err]

            subsampling = False
            code = RepetitionCodeStimCircuit(D_NEW, T, xbasis=XBASIS, resets=_RESETS, 
                                            noise_list=noise_list, subsampling=False)
            model = code.circuits[LOGICAL].detector_error_model(decompose_errors=False)
            matching = pymatching.Matching.from_detector_error_model(model)

            ### DECODING ###
            result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS, 
                                            qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
                                            nb_intervals=nb_intervals)
            num_errors_kde.append(result_kde.num_errors)

            result_hard = cpp_soft_info.decode_hard_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
                                                        qubit_mapping, kde_dict, _DETAILED,
                                                        relError=rel_error, absError=-1)
            num_errors_hard.append(result_hard.num_errors)
        

        print("num_errors_kde", num_errors_kde)
        print("num_errors_hard", num_errors_hard)
        print("mean num_errors_kde", np.mean(num_errors_kde))
        print("mean num_errors_hard", np.mean(num_errors_hard))

        result_kde_json = {
            "decoding": "kde",
            "num_errors": np.mean(num_errors_kde),
            "error_list": num_errors_kde,
            "additional_info": {
                "rel_error": rel_error,
                "bandwidth_linspace": lin,
                "num_points_bandwidths": num_points
            },
        }

        result_hard_json = {
            "decoding": "hard",
            "num_errors": np.mean(num_errors_hard),
            "error_list": num_errors_hard,
        }

         ############# SAVING THE RESULT ##############

        with open(file_name, "r") as f:
            data = json.load(f)
            if job_id not in data.keys():
                data[job_id] = [result_kde_json, result_hard_json]
            else:
                data[job_id].append(result_kde_json)
                data[job_id].append(result_hard_json)
        
        with open(file_name, "w") as f:
            json.dump(data, f, indent=4)
# Out:
# 21:46:41 Warning: Negative T2 error -0.03 % for qubit 115, setting to 0.. IN FILE: /Users/mha/My_Drive/Desktop/Studium/Physik/MSc/Semester_3/IBM/IBM_GIT/Soft-Info/src/soft_info/Hardware/backend_noise.py, LINE: 52
# Found jobs for backend ibm_sherbrooke with closest execution date 2024-03-15 15:04:39.994509+00:00.
# Decoding jobs of 2024-03-15 11:36:53.764000+00:00 calibration:   0%|          | 0/12 [00:00<?, ?it/s]
# start subsampling
# Samples::  68%|██████▊   | 19/28 [13:04<06:11, 41.27s/it]
# Decoding jobs of 2024-03-15 11:36:53.764000+00:00 calibration:   0%|          | 0/12 [13:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 83
#      78     result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
#      79                                     qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
#      80                                     nb_intervals=nb_intervals)
#      81     num_errors_kde.append(result_kde.num_errors)
# ---> 83     result_hard = cpp_soft_info.decode_hard_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
#      84                                                 qubit_mapping, kde_dict, _DETAILED,
#      85                                                 relError=rel_error, absError=-1)
#      86     num_errors_hard.append(result_hard.num_errors)
#      89 print("num_errors_kde", num_errors_kde)
#
# KeyboardInterrupt:
