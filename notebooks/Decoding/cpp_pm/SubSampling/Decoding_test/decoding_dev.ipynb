# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data

# %%
from result_saver import SaverProvider
provider = SaverProvider()

# %%
from Scratch import metadata_loader
import numpy as np
from tqdm import tqdm

DEVICE = "ibm_sherbrooke"
LOGICAL = str(1)
XBASIS = True
ROUNDS = 10


# Load the metadata
md = metadata_loader(True, True)
md = md[md["job_status"] == "JobStatus.DONE"]
md = md[md["code"] == "RepetitionCodeCircuit"]
md = md[md["descr"] == 'subset RepCodes']
md = md.dropna(subset=["rounds"])
md = md[md["meas_level"] == 1]
md['rounds'] = md['rounds'].astype(int)
md['distance'] = md['distance'].astype(int)

md = md[md["backend_name"] == DEVICE]
md = md[md["logical"] == LOGICAL]
md = md[md["xbasis"] == XBASIS]
md = md[md["rounds"] == ROUNDS]

print(md.shape)
md
# Out:
# (20, 18)
#                          creation_date             notebook_name  \
# 2775  2024-03-15 12:45:34.832000+01:00  Sherbrooke_RepCodes_jobs
# 2774  2024-03-15 12:45:32.193000+01:00  Sherbrooke_RepCodes_jobs
# 2773  2024-03-15 12:45:29.781000+01:00  Sherbrooke_RepCodes_jobs
# 2772  2024-03-15 12:45:26.968000+01:00  Sherbrooke_RepCodes_jobs
# 2771  2024-03-15 12:45:24.470000+01:00  Sherbrooke_RepCodes_jobs
# 2770  2024-03-15 12:45:21.834000+01:00  Sherbrooke_RepCodes_jobs
# 2769  2024-03-15 12:45:19.348000+01:00  Sherbrooke_RepCodes_jobs
# 2768  2024-03-15 12:45:16.486000+01:00  Sherbrooke_RepCodes_jobs
# 2767  2024-03-15 12:45:13.106000+01:00  Sherbrooke_RepCodes_jobs
# 2766  2024-03-15 12:45:10.338000+01:00  Sherbrooke_RepCodes_jobs
# 2765  2024-03-15 12:45:07.454000+01:00  Sherbrooke_RepCodes_jobs
# 2764  2024-03-15 12:45:04.520000+01:00  Sherbrooke_RepCodes_jobs
# 2763  2024-03-15 12:45:02.070000+01:00  Sherbrooke_RepCodes_jobs
# 2762  2024-03-15 12:44:59.493000+01:00  Sherbrooke_RepCodes_jobs
# 2761  2024-03-15 12:44:56.684000+01:00  Sherbrooke_RepCodes_jobs
# 2760  2024-03-15 12:44:54.171000+01:00  Sherbrooke_RepCodes_jobs
# 2759  2024-03-15 12:44:51.664000+01:00  Sherbrooke_RepCodes_jobs
# 2758  2024-03-15 12:44:47.689000+01:00  Sherbrooke_RepCodes_jobs
# 2757  2024-03-15 12:44:44.940000+01:00  Sherbrooke_RepCodes_jobs
# 2756  2024-03-15 12:44:42.189000+01:00  Sherbrooke_RepCodes_jobs
#
#         backend_name                job_id  \
# 2775  ibm_sherbrooke  cqt39qp36d60008hyf3g
# 2774  ibm_sherbrooke  cqt39q636d60008hyf30
# 2773  ibm_sherbrooke  cqt39pe4x0mg008agq3g
# 2772  ibm_sherbrooke  cqt39npch2mg008qv0ng
# 2771  ibm_sherbrooke  cqt39n6txzj0008xymp0
# 2770  ibm_sherbrooke  cqt39mech2mg008qv0n0
# 2769  ibm_sherbrooke  cqt39ky4x0mg008agq30
# 2768  ibm_sherbrooke  cqt39k636d60008hyf2g
# 2767  ibm_sherbrooke  cqt39j6ch2mg008qv0m0
# 2766  ibm_sherbrooke  cqt39hp9nfw0008hrgjg
# 2765  ibm_sherbrooke  cqt39gy4x0mg008agq2g
# 2764  ibm_sherbrooke  cqt39g69nfw0008hrgj0
# 2763  ibm_sherbrooke  cqt39fdtxzj0008xymng
# 2762  ibm_sherbrooke  cqt39ex4x0mg008agq1g
# 2761  ibm_sherbrooke  cqt39e5ch2mg008qv0kg
# 2760  ibm_sherbrooke  cqt39dd36d60008hyf20
# 2759  ibm_sherbrooke  cqt39cx88ev000811j1g
# 2758  ibm_sherbrooke  cqt39bxtxzj0008xymn0
# 2757  ibm_sherbrooke  cqt39b536d60008hyf1g
# 2756  ibm_sherbrooke  cqt39an36d60008hyf10
#
#                                             tags  meas_level   shots  \
# 2775  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2774  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2773  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2772  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2771  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2770  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2769  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2768  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2767  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2766  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2765  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2764  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2763  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2762  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2761  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2760  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2759  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2758  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2757  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
# 2756  [Subset 52, 10 rounds, 1 log, xbasis=True]         1.0  6525.0
#
#       num_qubits      job_status                    execution_date  \
# 2775         NaN  JobStatus.DONE  2024-03-15 17:03:26.029321+01:00
# 2774         NaN  JobStatus.DONE  2024-03-15 17:02:58.242311+01:00
# 2773         NaN  JobStatus.DONE  2024-03-15 17:02:29.884951+01:00
# 2772         NaN  JobStatus.DONE  2024-03-15 17:01:27.951670+01:00
# 2771         NaN  JobStatus.DONE  2024-03-15 17:00:35.587462+01:00
# 2770         NaN  JobStatus.DONE  2024-03-15 17:00:06.957634+01:00
# 2769         NaN  JobStatus.DONE  2024-03-15 16:59:38.639003+01:00
# 2768         NaN  JobStatus.DONE  2024-03-15 16:59:10.470647+01:00
# 2767         NaN  JobStatus.DONE  2024-03-15 16:58:42.930504+01:00
# 2766         NaN  JobStatus.DONE  2024-03-15 16:58:15.369993+01:00
# 2765         NaN  JobStatus.DONE  2024-03-15 16:57:47.894027+01:00
# 2764         NaN  JobStatus.DONE  2024-03-15 16:57:20.093172+01:00
# 2763         NaN  JobStatus.DONE  2024-03-15 16:56:52.251731+01:00
# 2762         NaN  JobStatus.DONE  2024-03-15 16:56:23.821118+01:00
# 2761         NaN  JobStatus.DONE  2024-03-15 16:55:55.790100+01:00
# 2760         NaN  JobStatus.DONE  2024-03-15 16:55:28.008840+01:00
# 2759         NaN  JobStatus.DONE  2024-03-15 16:54:59.989351+01:00
# 2758         NaN  JobStatus.DONE  2024-03-15 16:54:32.595738+01:00
# 2757         NaN  JobStatus.DONE  2024-03-15 16:54:04.729630+01:00
# 2756         NaN  JobStatus.DONE  2024-03-15 16:53:37.204605+01:00
#
#                        code  distance  rounds logical            descr resets  \
# 2775  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2774  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2773  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2772  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2771  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2770  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2769  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2768  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2767  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2766  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2765  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2764  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2763  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2762  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2761  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2760  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2759  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2758  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2757  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
# 2756  RepetitionCodeCircuit        52      10       1  subset RepCodes    NaN
#
#      xbasis                                          path_info
# 2775   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2774   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2773   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2772   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2771   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2770   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2769   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2768   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2767   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2766   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2765   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2764   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2763   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2762   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2761   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2760   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2759   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2758   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2757   True  {'mean_gate_error': 0.007963147793478, 'min_ga...
# 2756   True  {'mean_gate_error': 0.007963147793478, 'min_ga...

# %% [markdown]
# # Group job ids by closest calibration date

# %%
from datetime import datetime
from Scratch import find_closest_calib_jobs
import pandas as pd

jobs_by_calibration_date = {}
for index, row in md.iterrows():
    job_id = row['job_id']

    _, _, calib_creation_date = find_closest_calib_jobs(tobecalib_job=job_id, verbose=False)

    if calib_creation_date not in jobs_by_calibration_date.keys():
        jobs_by_calibration_date[calib_creation_date] = [job_id]
    else:
        jobs_by_calibration_date[calib_creation_date].append(job_id)

# Takes 15s

# %%
print(jobs_by_calibration_date)
print()
print(f"num of calibrations: {len(jobs_by_calibration_date)}")
print(f"num of jobs per calibration: {([len(jobs) for jobs in jobs_by_calibration_date.values()])}")
# Out:
# {datetime.datetime(2024, 3, 15, 11, 45, 38, 394000, tzinfo=datetime.timezone.utc): ['cqt39qp36d60008hyf3g', 'cqt39q636d60008hyf30', 'cqt39pe4x0mg008agq3g', 'cqt39npch2mg008qv0ng', 'cqt39n6txzj0008xymp0', 'cqt39mech2mg008qv0n0', 'cqt39ky4x0mg008agq30', 'cqt39k636d60008hyf2g', 'cqt39j6ch2mg008qv0m0', 'cqt39hp9nfw0008hrgjg'], datetime.datetime(2024, 3, 15, 11, 44, 35, 475000, tzinfo=datetime.timezone.utc): ['cqt39gy4x0mg008agq2g', 'cqt39g69nfw0008hrgj0', 'cqt39fdtxzj0008xymng', 'cqt39ex4x0mg008agq1g', 'cqt39e5ch2mg008qv0kg', 'cqt39dd36d60008hyf20', 'cqt39cx88ev000811j1g', 'cqt39bxtxzj0008xymn0', 'cqt39b536d60008hyf1g', 'cqt39an36d60008hyf10']}

# %% [markdown]
# # Decode data

# %%
import json

import pymatching
import stim

from soft_info import get_noise_dict_from_backend, get_avgs_from_dict, get_repcode_IQ_map, RepetitionCodeStimCircuit
from Scratch import load_calibration_memory
from src import cpp_soft_info

file_name = "./results/decoding_test.json"
_DETAILED = False

rel_error = 1
_RESETS = False
nb_intervals = -1

# KDE BANDWIDTHS
lin = [0.4, 0.7, 20]
num_points = 51
bandwidths = np.linspace(lin[0], lin[1], lin[2])

for calib_date in jobs_by_calibration_date.keys():
    # get the noise dict of that date
    noise_dict = get_noise_dict_from_backend(provider, DEVICE, date = calib_date)

    # get the KDE of that date
    all_memories = load_calibration_memory(provider, tobecalib_backend=DEVICE, other_date=calib_date)
    kde_dict = cpp_soft_info.get_KDEs(all_memories, bandwidths, relError=rel_error, absError=-1, num_points=51) # Less num_points bcs just 1 bandwidth

    for job_id in tqdm(jobs_by_calibration_date[calib_date], desc=f"Decoding jobs of {calib_date} calibration"):
        d = md[md["job_id"] == job_id]["distance"].values[0] 
        T = md[md["job_id"] == job_id]["rounds"].values[0] # Should be 10

        # Get the job
        job = provider.retrieve_job(job_id)
        IQ_data = job.result().get_memory()
        
        # Get the layout 
        layout_des = job.deserialize_layout(job.initial_layouts()[0]) # only 1 layout
        layout = list(layout_des['link_qubit'].values()) + list(layout_des['code_qubit'].values())
        qubit_mapping = get_repcode_IQ_map(layout, synd_rounds=T)

        # Get the noise avgs
        avgs = get_avgs_from_dict(noise_dict, layout)
        noise_list = [avgs["two_gate"], avgs["single_gate"], avgs["t1_err"], avgs["t2_err"]]
        readout = avgs["readout"]
        soft_multiplicator = 0
        noise_list += [readout, readout*(1-soft_multiplicator), readout*soft_multiplicator]    
        #[twog_err, sglg_err, t1_err, t2_err, readout_err, hard_err, soft_err]

        subsampling = False
        code = RepetitionCodeStimCircuit(d, T, xbasis=XBASIS, resets=_RESETS, 
                                         noise_list=noise_list, subsampling=False)
        model = code.circuits[LOGICAL].detector_error_model(decompose_errors=False)
        matching = pymatching.Matching.from_detector_error_model(model)

        ### DECODING ###
        result_kde = cpp_soft_info.decode_IQ_kde(model, IQ_data, T, int(LOGICAL), _RESETS, 
                                         qubit_mapping, kde_dict, _DETAILED, relError=rel_error, absError=-1,
                                         nb_intervals=nb_intervals)
        
        result_kde_json = {
            "decoding": "kde",
            "num_errors": result_kde.num_errors,
            "additional_info": {
                "rel_error": rel_error,
                "bandwidth_linspace": lin,
                "num_points_bandwidths": num_points
            },
        }

        result_hard = cpp_soft_info.decode_hard_kde(model, IQ_data, T, int(LOGICAL), _RESETS,
                                                    qubit_mapping, kde_dict, _DETAILED,
                                                    relError=rel_error, absError=-1)

        result_hard_json = {
            "decoding": "hard",
            "num_errors": result_hard.num_errors,
        }

         ############# SAVING THE RESULT ##############

        with open(file_name, "r") as f:
            data = json.load(f)
            if job_id not in data.keys():
                data[job_id] = [result_kde_json, result_hard_json]
            else:
                data[job_id].append(result_kde_json)
                data[job_id].append(result_hard_json)
        
        with open(file_name, "w") as f:
            json.dump(data, f, indent=4)
# Out:
# 14:01:41 Warning: Negative T2 error -0.03 % for qubit 115, setting to 0.. IN FILE: /Users/mha/My_Drive/Desktop/Studium/Physik/MSc/Semester_3/IBM/IBM_GIT/Soft-Info/src/soft_info/Hardware/backend_noise.py, LINE: 52
# Found jobs for backend ibm_sherbrooke with closest execution date 2024-03-15 15:04:39.994509+00:00.
# Decoding jobs of 2024-03-15 11:45:38.394000+00:00 calibration:  30%|███       | 3/10 [04:23<10:12, 87.57s/it]
