# %% [markdown]
# # Load Data

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from result_saver import SaverProvider
provider = SaverProvider()

# %%
import numpy as np
from Scratch import metadata_loader

DEVICE = 'ibm_sherbrooke'

md = metadata_loader(_extract=True, _drop_inutile=True)
md = md[md["job_status"] == "JobStatus.DONE"]
md = md[md["notebook_name"] == "bigger_rep_codes"]
max_distance = int(max(md.distance))
max_distance = 30
md = md[md["distance"] == max_distance]
md = md[md["backend_name"]==DEVICE]

md = md[:2]

md
# Out:
#                         creation_date     notebook_name    backend_name  \
# 258  2023-10-30 09:45:17.340386+01:00  bigger_rep_codes  ibm_sherbrooke
# 76   2023-10-29 14:47:58.814875+01:00  bigger_rep_codes  ibm_sherbrooke
#
#                    job_id tags   shots tags_xp sampled_state  num_qubits  \
# 258  cmzpt78vcq70008qf1ag   []  1111.0     NaN           NaN         NaN
# 76   cmz653m3r3vg008wf9j0   []  1111.0     NaN           NaN         NaN
#
#          job_status extra  optimization_level                   code  \
# 258  JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
# 76   JobStatus.DONE   NaN                 NaN  RepetitionCodeCircuit
#
#      distance rounds logical        layout  \
# 258      30.0     30       0  _is_hex=True
# 76       30.0     30       1  _is_hex=True
#
#                                                  descr
# 258  Run bigger Repetition codes v4: new distances ...
# 76                         Run bigger Repetition codes

# %%
memories = {}
for job_id, logical in zip(md.job_id, md.logical):
    mmr_name = f"mmr_log_{logical}"
    memories[mmr_name] = provider.retrieve_job(job_id).result().get_memory()

memory = memories["mmr_log_1"][:]

# %% [markdown]
# # UF Decoder

# %%
import pickle
from qiskit_qec.circuits import RepetitionCodeCircuit
from soft_info import get_repcode_layout, get_KDEs, get_counts

layout = get_repcode_layout(distance=max_distance, backend=provider.get_backend("ibm_nazca"), _is_hex=True)
kde_dict, scaler_dict = get_KDEs(provider, 'cmz653m3r3vg008wf9j0')
code = RepetitionCodeCircuit(max_distance, max_distance)

# %% [markdown]
# # PyMatching

# %%
import stim
import pymatching

d = max_distance
T = max_distance

circuit = stim.Circuit.generated("repetition_code:memory",
                                 distance=d,
                                 rounds=T,
                                 after_clifford_depolarization=0.1)

model = circuit.detector_error_model(decompose_errors=True)
matching = pymatching.Matching.from_detector_error_model(model)

# %%
import cProfile
import pstats


from tqdm import tqdm
from soft_info import get_counts, soft_reweight_pymatching, counts_to_det_syndr, draw_matching_graph, reweight_edges_to_one



def main():
    VERBOSE = False

    #actual_observables = np.array([[False]]) # hardcoded, can be retrieved
    num_errors = 0

    i = 0
    w_idx_lst = []
    for shot in tqdm(range(len(memory))[:20]):
        i += 1
        IQ_data = memory[shot]

        counts = get_counts([IQ_data], kde_dict, scaler_dict, layout, T, verbose=False)
        count_key = next(iter(counts.keys()))
        
        actual_observables = [(int(count_key[0])+1)%2]
        soft_reweight_pymatching(matching, d, T, IQ_data, kde_dict, layout, scaler_dict, common_measure=0.01, verbose=False)  
        #reweight_edges_to_one(matching)

        array_processed_string = counts_to_det_syndr(count_key, _resets=False, verbose=False)

        predicted_observables = matching.decode(array_processed_string)

        if predicted_observables == actual_observables: #== [0]:
            continue
        num_errors += 1
        #print("actual_observables:", actual_observables)
        #print("predicted_observables:", predicted_observables)
        print("num_errors:", num_errors)

        #print(f"Wrong decoding at index {i}")
        w_idx_lst.append(i)

        
        if VERBOSE:
            print("Count key:", count_key)
            print("count_string_to_syndromes:", array_processed_string)
            print("actual_observables:", actual_observables)
            print("predicted_observables:", predicted_observables)

        
        if VERBOSE:
            matched_edges = matching.decode_to_edges_array(array_processed_string)
            print("matched_edges: ", matched_edges)
            print("Estimated flip:", predicted_observables)
            
        if VERBOSE:
            draw_matching_graph(matching, d, T, syndromes=array_processed_string, matched_edges=matched_edges, figsize=(10, 10))

    print("Num errors:", num_errors)

# %%
if __name__ == "__main__":
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats()
# Out:
# 100%|██████████| 20/20 [00:16<00:00,  1.24it/s]
# Num errors: 0
#          15342177 function calls (15162160 primitive calls) in 16.196 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001   16.196   16.196 /var/folders/_3/n7zzdff5239886c9gmhrk6yr0000gn/T/ipykernel_62572/3074820388.py:10(main)
#        20    0.040    0.002   15.965    0.798 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/Probabilities/probabilities.py:46(get_counts)
#     18000    0.072    0.000   15.915    0.001 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/Probabilities/probabilities.py:15(estimate_outcome)
#     36000    0.177    0.000   14.473    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/neighbors/_kde.py:245(score_samples)
#     36000   10.141    0.000   12.002    0.000 {method 'kernel_density' of 'sklearn.neighbors._kd_tree.BinaryTree' objects}
#     90000    0.633    0.000    4.686    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:644(check_array)
#     54000    0.115    0.000    3.188    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/base.py:509(_validate_data)
#     90000    0.393    0.000    1.804    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:92(_assert_all_finite)
#     18000    0.018    0.000    1.359    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_set_output.py:155(wrapped)
#     18000    0.070    0.000    1.300    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:988(transform)
#    180000    0.055    0.000    1.294    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:282(isdtype)
#    180000    0.106    0.000    1.239    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:75(isdtype)
# 360000/180000    0.513    0.000    1.069    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:87(_isdtype_single)
#    180000    0.057    0.000    1.058    0.000 {built-in method builtins.any}
#    270000    0.068    0.000    0.767    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:96(<genexpr>)
#   1368000    0.483    0.000    0.603    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:227(__getattr__)
#    180000    0.178    0.000    0.371    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:33(seterr)
#     54000    0.042    0.000    0.330    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:1404(check_is_fitted)
#     90000    0.065    0.000    0.295    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2177(sum)
#     90000    0.131    0.000    0.274    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:330(_num_samples)
#     54000    0.046    0.000    0.261    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:1366(_is_fitted)
#    288000    0.150    0.000    0.259    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:70(_is_numpy_namespace)
#     90000    0.046    0.000    0.244    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:430(__enter__)
#    180000    0.035    0.000    0.241    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:82(<genexpr>)
#     90000    0.069    0.000    0.224    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:360(_asarray_with_order)
#     90000    0.075    0.000    0.224    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/fromnumeric.py:71(_wrapreduction)
#    288000    0.097    0.000    0.219    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/_config.py:32(get_config)
#     90000    0.044    0.000    0.217    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:435(__exit__)
#    180000    0.062    0.000    0.204    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:289(get_namespace)
#   1492937    0.119    0.000    0.203    0.000 {built-in method builtins.isinstance}
#     54000    0.118    0.000    0.198    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:1398(<listcomp>)
#        20    0.068    0.003    0.167    0.008 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/matching_graph.py:15(soft_reweight_pymatching)
#     90000    0.046    0.000    0.165    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/warnings.py:165(simplefilter)
#    180000    0.139    0.000    0.151    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:132(geterr)
#   1620072    0.147    0.000    0.147    0.000 {built-in method builtins.hasattr}
#   1530040    0.133    0.000    0.133    0.000 {built-in method builtins.getattr}
#     54000    0.028    0.000    0.121    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/base.py:374(_check_n_features)
#     90000    0.062    0.000    0.114    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/warnings.py:181(_add_filter)
#    180000    0.073    0.000    0.107    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:247(asarray)
#     90000    0.104    0.000    0.104    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    288000    0.060    0.000    0.091    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/_config.py:24(_get_threadlocal_config)
#     54000    0.068    0.000    0.087    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:277(_num_features)
#     90000    0.018    0.000    0.084    0.000 <frozen abc>:117(__instancecheck__)
#     90000    0.071    0.000    0.077    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/warnings.py:466(__enter__)
#     36000    0.046    0.000    0.068    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/numeric.py:274(full)
#     90000    0.028    0.000    0.066    0.000 {built-in method _abc._abc_instancecheck}
#    576004    0.060    0.000    0.060    0.000 {method 'endswith' of 'str' objects}
#     90000    0.051    0.000    0.056    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/warnings.py:487(__exit__)
#     90000    0.038    0.000    0.055    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:581(_ensure_no_complex_data)
#    306000    0.048    0.000    0.048    0.000 {built-in method numpy.asarray}
#     54000    0.026    0.000    0.047    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/base.py:420(_check_feature_names)
#     51560    0.024    0.000    0.045    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:616(add_edge)
#     18000    0.008    0.000    0.040    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_set_output.py:97(_wrap_data_with_container)
#     90000    0.039    0.000    0.039    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/fromnumeric.py:72(<dictcomp>)
#     90000    0.018    0.000    0.038    0.000 <frozen abc>:121(__subclasscheck__)
#     90000    0.038    0.000    0.038    0.000 {method 'remove' of 'list' objects}
#     90000    0.025    0.000    0.035    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:639(_is_extension_array_dtype)
#     18000    0.015    0.000    0.032    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_set_output.py:63(_get_output_config)
#    288000    0.031    0.000    0.031    0.000 {method 'copy' of 'dict' objects}
#     90000    0.031    0.000    0.031    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/warnings.py:440(__init__)
#    108000    0.022    0.000    0.030    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/scipy/sparse/_base.py:1461(issparse)
#    180000    0.029    0.000    0.029    0.000 {built-in method numpy.seterrobj}
#    360000    0.026    0.000    0.026    0.000 {built-in method numpy.geterrobj}
#     90000    0.019    0.000    0.024    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:591(_check_estimator_name)
#        20    0.000    0.000    0.023    0.001 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:859(edges)
#        20    0.023    0.001    0.023    0.001 {built-in method pymatching._cpp_pymatching.get_edges}
#        20    0.001    0.000    0.021    0.001 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:7(counts_to_det_syndr)
#     35400    0.021    0.000    0.021    0.000 {built-in method builtins.round}
#     90000    0.020    0.000    0.020    0.000 {built-in method _abc._abc_subclasscheck}
#    198048    0.020    0.000    0.020    0.000 {method 'startswith' of 'str' objects}
#    180000    0.018    0.000    0.018    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/_array_api.py:170(_check_device_cpu)
#     54000    0.012    0.000    0.018    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/inspect.py:292(isclass)
#    219324    0.017    0.000    0.017    0.000 {built-in method builtins.len}
#     51560    0.017    0.000    0.017    0.000 {built-in method pymatching._cpp_pymatching.add_edge}
#      1843    0.002    0.000    0.017    0.000 {method 'join' of 'str' objects}
#    195611    0.017    0.000    0.017    0.000 {method 'get' of 'dict' objects}
#    270000    0.017    0.000    0.017    0.000 {built-in method _warnings._filters_mutated}
#     54000    0.013    0.000    0.016    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/sklearn/utils/validation.py:1987(_get_feature_names)
#         1    0.000    0.000    0.016    0.016 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:666(__new__)
#         1    0.000    0.000    0.015    0.015 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:763(get_lock)
#         1    0.000    0.000    0.015    0.015 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:90(__init__)
#         1    0.000    0.000    0.015    0.015 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:116(create_mp_lock)
#         1    0.000    0.000    0.015    0.015 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/context.py:70(RLock)
#         1    0.000    0.000    0.015    0.015 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/synchronize.py:186(__init__)
#         1    0.000    0.000    0.015    0.015 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/synchronize.py:50(__init__)
#     90000    0.015    0.000    0.015    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:426(__init__)
#        20    0.000    0.000    0.014    0.001 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:192(decode)
#        20    0.014    0.001    0.014    0.001 {built-in method pymatching._cpp_pymatching.decode}
#         1    0.000    0.000    0.012    0.012 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/resource_tracker.py:153(register)
#         1    0.000    0.000    0.012    0.012 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/resource_tracker.py:161(_send)
#         1    0.000    0.000    0.012    0.012 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/resource_tracker.py:78(ensure_running)
#         1    0.000    0.000    0.011    0.011 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/util.py:447(spawnv_passfds)
#         1    0.011    0.011    0.011    0.011 {built-in method _posixsubprocess.fork_exec}
#        21    0.000    0.000    0.010    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1161(__iter__)
#        21    0.000    0.000    0.010    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1326(refresh)
#        22    0.000    0.000    0.010    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1465(display)
#        20    0.000    0.000    0.010    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1199(update)
#     90000    0.010    0.000    0.010    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2172(_sum_dispatcher)
#     90000    0.009    0.000    0.009    0.000 {method 'insert' of 'list' objects}
#        22    0.000    0.000    0.009    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:460(print_status)
#        22    0.000    0.000    0.008    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:454(fp_write)
#        46    0.000    0.000    0.008    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:193(inner)
#     54000    0.008    0.000    0.008    0.000 {built-in method builtins.vars}
#     36000    0.008    0.000    0.008    0.000 {built-in method numpy.empty}
#        24    0.000    0.000    0.007    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:563(flush)
#     17400    0.007    0.000    0.007    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:44(<genexpr>)
#     17400    0.007    0.000    0.007    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:53(<genexpr>)
#        25    0.000    0.000    0.007    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:604(wait)
#        25    0.000    0.000    0.007    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:288(wait)
#     90021    0.007    0.000    0.007    0.000 {method 'items' of 'dict' objects}
#       196    0.007    0.000    0.007    0.000 {method 'acquire' of '_thread.lock' objects}
#        40    0.005    0.000    0.005    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/Hardware/transpile_rep_code.py:35(get_repcode_IQ_map)
#     36000    0.004    0.000    0.004    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/multiarray.py:1080(copyto)
#     18000    0.004    0.000    0.004    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/lib/type_check.py:120(real)
#     18000    0.003    0.000    0.003    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/lib/type_check.py:166(imag)
#       3/1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:1165(_find_and_load)
#       3/1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:1120(_find_and_load_unlocked)
#       3/1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:666(_load_unlocked)
#       2/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:934(exec_module)
#         1    0.000    0.000    0.002    0.002 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:953(__init__)
#       8/2    0.000    0.000    0.002    0.001 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#       2/1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#         1    0.000    0.000    0.002    0.002 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/resource_tracker.py:1(<module>)
#        20    0.002    0.000    0.002    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:98(<listcomp>)
#     18000    0.002    0.000    0.002    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/core/multiarray.py:1393(may_share_memory)
#         3    0.000    0.000    0.002    0.001 <frozen importlib._bootstrap>:566(module_from_spec)
#     18000    0.002    0.000    0.002    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/lib/type_check.py:116(_real_dispatcher)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:1231(create_module)
#         1    0.002    0.002    0.002    0.002 {built-in method _imp.create_dynamic}
#        72    0.000    0.000    0.002    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:259(schedule)
#     18000    0.002    0.000    0.002    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/numpy/lib/type_check.py:162(_imag_dispatcher)
#        28    0.000    0.000    0.002    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:626(write)
#      1240    0.001    0.000    0.001    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:706(add_boundary_edge)
#        28    0.000    0.000    0.001    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:548(_schedule_flush)
#        22    0.000    0.000    0.001    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1151(__str__)
#        72    0.001    0.000    0.001    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/zmq/sugar/socket.py:621(send)
#        22    0.000    0.000    0.001    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:467(format_meter)
#         1    0.000    0.000    0.001    0.001 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:441(status_printer)
#      1240    0.001    0.000    0.001    0.000 {built-in method pymatching._cpp_pymatching.add_boundary_edge}
#        40    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:377(disp_len)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/_monitor.py:30(__init__)
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:373(_text_width)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1266(close)
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        20    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:176(_syndrome_array_to_detection_events)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1007(get_code)
#       154    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#      1038    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:374(<genexpr>)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1054(_find_spec)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       6/3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__import__}
#       600    0.000    0.000    0.000    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:83(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:332(_screen_shape_linux)
#       600    0.000    0.000    0.000    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:72(<genexpr>)
#        26    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:555(__init__)
#        25    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:102(acquire)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1496(find_spec)
#       620    0.000    0.000    0.000    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:22(<genexpr>)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1464(_get_spec)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:938(start)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1604(find_spec)
#        96    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1185(is_alive)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:682(_get_free_pos)
#        20    0.000    0.000    0.000    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/PyMatching/detector_syndromes.py:31(<listcomp>)
#        43    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/joblib/externals/loky/backend/__init__.py:7(_make_name)
#        43    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:400(format_interval)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/tempfile.py:153(__next__)
#        20    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/qiskit/result/counts.py:32(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#         3    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:63(__iter__)
#         2    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:685(<setcomp>)
#        26    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:236(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1127(get_data)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:849(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/tempfile.py:142(rng)
#        25    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1447(format_dict)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/random.py:119(__init__)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/signal.py:67(pthread_sigmask)
#        21    0.000    0.000    0.000    0.000 {built-in method now}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/random.py:128(seed)
#        44    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:272(_is_ascii)
#       121    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:231(__call__)
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x10334d8a0}
#        25    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:106(release)
#         2    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#      1016    0.000    0.000    0.000    0.000 {built-in method unicodedata.east_asian_width}
#        20    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:27(__exit__)
#         4    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/signal.py:70(<genexpr>)
#        96    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1118(_wait_for_tstate_lock)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#        58    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        13    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/signal.py:24(_int_to_enum)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:346(<listcomp>)
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:186(__format__)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/enum.py:685(__call__)
#        25    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:212(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#        40    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:1704(num_detectors)
#        22    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        48    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1161(ident)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/util.py:186(__init__)
#        72    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:137(_event_pipe)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1287(fp_write)
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:153(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:265(_supports_unicode)
#        20    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:689(_decr_instances)
#        28    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:521(_is_master_process)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:392(cached)
#        25    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1446(current_thread)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:85(add)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:107(__init__)
#       462    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        40    0.000    0.000    0.000    0.000 {built-in method pymatching._cpp_pymatching.get_num_detectors}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:567(_get_cached)
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:128(<listcomp>)
#        20    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/pymatching/matching.py:1665(boundary)
#        25    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:276(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:113(__exit__)
#         2    0.000    0.000    0.000    0.000 {built-in method _signal.pthread_sigmask}
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:138(__getattr__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1599(_get_spec)
#         4    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:110(__enter__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py:1(<module>)
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        25    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:264(__enter__)
#       108    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/functools.py:393(__get__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:155(__init__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1317(_make_invoke_excepthook)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/random.py:480(choices)
#        25    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:279(_is_owned)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 <frozen os>:674(__getitem__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:300(_args_from_interpreter_flags)
#        25    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:267(__exit__)
#        28    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/util.py:171(register_after_fork)
#        25    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:273(_release_save)
#        26    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#        98    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:568(is_set)
#        82    0.000    0.000    0.000    0.000 {built-in method time.time}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:778(spec_from_file_location)
#         3    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:151(wrapper_setattr)
#         2    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        97    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        26    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1146(path_stats)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/random.py:493(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:53(_commit_removals)
#         1    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#        20    0.000    0.000    0.000    0.000 {built-in method pymatching._cpp_pymatching.get_boundary}
#        24    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:405(parent)
#        31    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/weakref.py:164(__setitem__)
#         4    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        43    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#        31    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/enum.py:1091(__new__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:748(find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:642(_classify_pyc)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:186(disable_on_exception)
#        32    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1030(__exit__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:110(remove)
#         3    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/retworkx/namespace.py:68(find_spec)
#        80    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         3    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/_distutils_hack/__init__.py:89(find_spec)
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1026(__enter__)
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:111(__format__)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        25    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         3    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:226(__init__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#        29    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:920(find_spec)
#        28    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:804(_newname)
#         3    0.000    0.000    0.000    0.000 {built-in method posix.close}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:675(_validate_timestamp_pyc)
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:167(colour)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py:36(set_executable)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1421(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.write}
#         3    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/qiskit/namespace.py:64(find_spec)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1214(daemon)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/threading.py:1199(daemon)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:21(__enter__)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/ipykernel/iostream.py:364(fileno)
#        20    0.000    0.000    0.000    0.000 /Users/mha/My Drive/Desktop/Studium/Physik/MSc/Semester 3/IBM/IBM GIT/Soft-Info/src/soft_info/Probabilities/probabilities.py:100(<lambda>)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/_weakrefset.py:17(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1239(exec_module)
#         3    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 <frozen os>:756(encode)
#        25    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        22    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:163(colour)
#        27    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        27    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:221(__eq__)
#         4    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:599(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen os>:806(fsencode)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/weakref.py:347(__new__)
#         4    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:124(__eq__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/weakref.py:352(__init__)
#         8    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/resource_tracker.py:54(ResourceTracker)
#         3    0.000    0.000    0.000    0.000 {built-in method _imp.find_frozen}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:180(_path_isabs)
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1158(__hash__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/resource_tracker.py:56(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/_virtualenv.py:53(find_spec)
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1039dbca8}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1097(__init__)
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#         6    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         2    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1154(_comparable)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/synchronize.py:90(_make_methods)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/context.py:237(get_context)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:251(_is_utf)
#         8    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1220(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1148(__del__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:98(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:290(_optim_args_from_interpreter_flags)
#         2    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.exec_dynamic}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:413(has_location)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/context.py:197(get_start_method)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/utils.py:281(_screen_shape_wrapper)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1122(get_filename)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py:43(get_executable)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:931(create_module)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/util.py:48(debug)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/tqdm/std.py:1302(<lambda>)
#         1    0.000    0.000    0.000    0.000 /Users/mha/.local/share/virtualenvs/Soft-Info-Sk8aHGSa/lib/python3.11/site-packages/_distutils_hack/__init__.py:96(<lambda>)
