# %%
from result_saver import SaverProvider, metadata_helper, metadata_loader
import pandas as pd
import numpy as np

# %%
# reorder the metadata

metadata = metadata_loader()
metadata = metadata.drop(columns=['time_str','day_str', 'test', 'descr', 'n_shots', 'num_qubits', 'meas_level', 'sampled_state'])
order = [
    'creation_date', 'notebook_name',  'backend_name', 'backend_options', 
    'additional_metadata', 'job_id', 'job_name', 'job_metadata', 'tags'
]

metadata = metadata[order]
metadata.head(5)
# Out:
#                        creation_date notebook_name  backend_name  \
# 23  2023-10-24 17:40:45.994179+02:00       KDE_Jak   ibmq_manila
# 22  2023-10-24 17:38:13.246957+02:00       KDE_Jak   ibmq_manila
# 21  2023-10-24 17:10:24.109707+02:00       KDE_Jak  ibmq_jakarta
# 20  2023-10-24 16:55:47.613514+02:00       KDE_Jak  ibmq_jakarta
# 19  2023-10-24 15:42:07.022802+02:00     plot_IQ_2   ibmq_manila
#
#                                       backend_options  \
# 23  {'meas_level': 1, 'init_qubits': True, 'meas_r...
# 22  {'meas_level': 1, 'init_qubits': True, 'meas_r...
# 21  {'shots': 1000000, 'memory': False, 'meas_leve...
# 20  {'memory': False, 'meas_level': 1, 'init_qubit...
# 19  {'meas_level': 1, 'init_qubits': True, 'meas_r...
#
#                       additional_metadata                job_id  job_name  \
# 23  {'sampled_state': 1, 'num_qubits': 1}  cmvyazbk20pg008epbzg       NaN
# 22  {'sampled_state': 1, 'num_qubits': 1}  cmvy9sf23ve0008zm1bg       NaN
# 21  {'sampled_state': 0, 'num_qubits': 1}  cmvxwr3tjjb00081ccp0       NaN
# 20  {'sampled_state': 1, 'num_qubits': 1}  cmvxnwzk20pg008epb80       NaN
# 19                                    NaN  cmvwkbnjad30008ec01g       NaN
#
#    job_metadata tags
# 23           {}   []
# 22           {}   []
# 21           {}   []
# 20           {}   []
# 19           {}   []

# %%
metadata.to_json('job_metadata.json', orient='records', indent=4)
